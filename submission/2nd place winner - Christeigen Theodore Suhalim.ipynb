# %% [markdown]
# Various CSV files are provided in this challenge. Before building a predictive model, it is required to preprocess each CSV file and merge them into a single CSV file. First, let us load all the provided CSV files into Panda Dataframes.

# %%
import re
import pandas as pd
import numpy as np
from toolz import *
from toolz.curried import *

# paths to all the csvs files provided in the challenge.
trainPath   = "/content/train.csv"
testPath    = "/content/test.csv" 
microPath   = "/content/properties.csv"
macrosPaths = ["/content/cpi.csv", "/content/interest.csv", "/content/rentIndex.csv", "/content/vacant.csv"]
geoPath     = "/content/geo_attributes.csv"

# load the csvs into pandas's Dataframe.
## load train&test_keys that contain unique identifier for each observation
train_keys = pd.read_csv(trainPath).assign(train = 1)
test_keys  = pd.read_csv(testPath).assign(train = 0).assign(price = pd.NA)
keys       = pd.concat([train_keys, test_keys])
keys       = keys.rename(columns = {"contractDate" : "date"})

## merge key with micro to borrow the date information in key.
_micro = pd.read_csv(microPath)
micro  = pd.merge(_micro, keys, on = "property_key")

## load all the macro files
macros = []
for macrosPath in macrosPaths:
    df = pd.read_csv(macrosPath)
    df = df.rename(columns = {"Data Series" : "date"})
    macros.append(df)

# load geo
geo = pd.read_csv(geoPath)

# %%
micro.isnull().sum()
# Out:
# area                0
# floorRange          0
# propertyType        0
# district            0
# typeOfArea          0
# tenure              0
# street              0
# project             0
# marketSegment       0
# property_key        0
# date                0
# price            2331
# train               0
# dtype: int64

# %% [markdown]
# the data has no missing values beside the target variable (price) in test. So we don't need to do data imputation

# %% [markdown]
# Now let's define preprocessing functions for micro and macro data. For micro data we performed 4 preprocessing:
#
# 1.   encode floorRange with ordinal encoder
# 2.   categorizing the tenure column into binary (freehold|lease)
# 3.   encode typeOfArea, propertyType, marketSegment with one hot encoding
# 4.   make 3 new variables called day, month, and year

# %%
def preprocess_micro(micro):    
    """
    preprocess micro data properties.csv
    """
    def _floorRange(row):
      merged_mapped = []
      unique_merged = sorted(micro["floorRange"].unique().tolist())
      for value in micro["floorRange"]:
        index = unique_merged.index(value)
        merged_mapped.append(index)
      return merged_mapped
    
    def _tenure(row):
        """
        some tenures are too rare to be used as variables.
        Hence simply making tenure feature to 1 if freehold else 0.
        """
        tenure = row["tenure"]    
        if tenure == "Freehold" : row["tenure"] = 1
        else                    : row["tenure"] = 0        
        return row
    merged_mapped = _floorRange(micro)
    micro = (micro
             .drop(["floorRange"], axis = 1)
             .assign(floorRange = merged_mapped)
             .apply(_tenure, axis = 1))
    micro["date"] = pd.to_datetime(micro["date"])
    micro.loc[micro['typeOfArea'] == "Land", 'typeOfArea'] = 0
    micro.loc[micro['typeOfArea'] == "Strata", 'typeOfArea'] = 1
    micro['year'] = micro['date'].dt.year
    micro['month'] = micro['date'].dt.month
    micro['day'] = micro['date'].dt.day
    dummy=pd.get_dummies(micro['propertyType'])
    dummy1=pd.get_dummies(micro['marketSegment'])
    micro = pd.concat([micro, dummy, dummy1], axis = 1, join = "inner")
    micro["typeOfArea"] = micro["typeOfArea"].astype(int)
    micro = micro.drop(["propertyType", "marketSegment"], axis = 1)
    return micro

# %% [markdown]
# For macro data, some informations are available only in quaterly resolution, we need to re-format quaterly to monthly using simple linear interpolation.

# %%
def preprocess_macros(cpi, interest, rentIndex, vacant):
    """
    four files are considered as macro-related files :
        * cpi.csv
        * interest.csv
        * rentIndex.csv
        * vacant.csv
    """
    
    def yq2ym(df):
        """
        convert year-quater in string format to monthly period
        """
        
        # repeat the first row for desired interpolation result
        df = pd.concat([df.head(0), df])
        df.at[0, "date"] = "2023 1Q "
            
        df["date"] = (pd.to_datetime((df["date"]
                                      .str
                                      .replace(r"(\d+) (\d)Q ", r"\1-Q\2")))
                      .dt
                      .to_period('M'))        
        df = df.set_index("date").resample("M", convention = "end").interpolate("linear")        
        return df    

    def ym2ym(df):
        """
         convert year-month in string format to monthly period
        """
        df["date"] = (pd.to_datetime(df["date"], format = "%Y %b ")
                      .dt
                      .to_period('M'))
        return df
    
    def mergeDfs(dfs, on):        
        """
        join dataframes into one
        """
        # grab first dataframe
        all_merged = dfs[0]
        # loop through all but first data frame
        for to_merge in dfs[1:]:
            # result of merge replaces first or previously
            # merged data frame w/ all previous fields
            all_merged = pd.merge(all_merged, to_merge,
                                  how = 'inner',
                                  on  = on)
        return all_merged
    
    # apply appropriate date conversion function for each dataframe
    dfs = [ym2ym(cpi), ym2ym(interest), yq2ym(rentIndex), yq2ym(vacant)]
    
    # join all dataframs into one
    df = mergeDfs(dfs, on = "date")   
    # convert peroid[M] to datetime
    df["date"] = df["date"].dt.to_timestamp()    
    # shift month + 3 
    df["date"] = df["date"] + pd.DateOffset(months=+3)
    
    return df

# %% [markdown]
# Now let's apply the two functions defined above to the micro and macro data.

# %%
micro = preprocess_micro(micro)
macro = preprocess_macros(*macros)
# Out:
# <ipython-input-4-ae9d572d4b97>:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   .replace(r"(\d+) (\d)Q ", r"\1-Q\2")))
# <ipython-input-4-ae9d572d4b97>:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   .replace(r"(\d+) (\d)Q ", r"\1-Q\2")))

# %% [markdown]
# We merge the preprocessed micro and macro data. Also, we fill in the missing values generated from the merging process using simple mean imputation.

# %%
_merged = pd.merge(micro, macro, on = "date", how = "left")
merged  = pd.merge(_merged, geo, on = ["street", "project", "district"], how = "left")
merged  = merged.fillna(merged.mean())
# Out:
# <ipython-input-14-1807e09f7ccd>:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   merged  = merged.fillna(merged.mean())
# <ipython-input-14-1807e09f7ccd>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged  = merged.fillna(merged.mean())

# %%
train = mergeds[mergeds["train"] == 1]
test  = mergeds[mergeds["train"] == 0]

# %% [markdown]
# # **MODELING WITH PYCARET**

# %%
# !pip install pycaret[full] -q

# %% [markdown]
# Do some set up with pycaret that define the target variable, numeric features, categorical features, and date features.

# %%
from pycaret.regression import *
exp_reg101 = setup(data=train, 
                   target='price', 
                   session_id=123, 
                   numeric_features=['area', 'district', 'typeOfArea', 'tenure', 
                                     'CPI', 'InterestRate',
                                     'RentIndex', 'Available', 'Vacant', 'lat', 'lng', 'num_schools_1km',
                                     'num_supermarkets_500m', 'num_mrt_stations_500m', 'floorRange', 'year',
                                     'month', 'day', 'Apartment', 'Condominium', 'Detached',
                                     'Executive Condominium', 'Semi-detached', 'Strata Detached',
                                     'Strata Semi-detached', 'Strata Terrace', 'Terrace', 'CCR', 'OCR',
                                     'RCR'], 
                   categorical_features=["street", "project", "property_key"], 
                   date_features=["date"])
# Out:
# <style type="text/css">
# #T_09900_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_09900" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09900_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_09900_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09900_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09900_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_09900_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09900_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_09900_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_09900_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_09900_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_09900_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_09900_row3_col1" class="data row3 col1" >(62949, 36)</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_09900_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_09900_row4_col1" class="data row4 col1" >(62949, 38)</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_09900_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_09900_row5_col1" class="data row5 col1" >(44064, 38)</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_09900_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_09900_row6_col1" class="data row6 col1" >(18885, 38)</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_09900_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_09900_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_09900_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_09900_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_09900_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_09900_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_09900_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_09900_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_09900_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_09900_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_09900_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_09900_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_09900_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_09900_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_09900_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_09900_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_09900_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_09900_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_09900_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_09900_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_09900_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_09900_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_09900_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_09900_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_09900_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_09900_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_09900_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_09900_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_09900_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_09900_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_09900_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_09900_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_09900_row22_col1" class="data row22 col1" >d30d</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_6200d th {
#   text-align: left;
# }
# #T_6200d_row0_col0, #T_6200d_row0_col1, #T_6200d_row0_col5, #T_6200d_row0_col6, #T_6200d_row1_col0, #T_6200d_row1_col2, #T_6200d_row1_col3, #T_6200d_row1_col4, #T_6200d_row2_col0, #T_6200d_row2_col1, #T_6200d_row2_col2, #T_6200d_row2_col3, #T_6200d_row2_col4, #T_6200d_row2_col5, #T_6200d_row2_col6, #T_6200d_row3_col0, #T_6200d_row3_col1, #T_6200d_row3_col2, #T_6200d_row3_col3, #T_6200d_row3_col4, #T_6200d_row3_col5, #T_6200d_row3_col6, #T_6200d_row4_col0, #T_6200d_row4_col1, #T_6200d_row4_col2, #T_6200d_row4_col3, #T_6200d_row4_col4, #T_6200d_row4_col5, #T_6200d_row4_col6, #T_6200d_row5_col0, #T_6200d_row5_col1, #T_6200d_row5_col2, #T_6200d_row5_col3, #T_6200d_row5_col4, #T_6200d_row5_col5, #T_6200d_row5_col6, #T_6200d_row6_col0, #T_6200d_row6_col1, #T_6200d_row6_col2, #T_6200d_row6_col3, #T_6200d_row6_col4, #T_6200d_row6_col5, #T_6200d_row6_col6, #T_6200d_row7_col0, #T_6200d_row7_col1, #T_6200d_row7_col2, #T_6200d_row7_col3, #T_6200d_row7_col4, #T_6200d_row7_col5, #T_6200d_row7_col6, #T_6200d_row8_col0, #T_6200d_row8_col1, #T_6200d_row8_col2, #T_6200d_row8_col3, #T_6200d_row8_col4, #T_6200d_row8_col5, #T_6200d_row8_col6, #T_6200d_row9_col0, #T_6200d_row9_col1, #T_6200d_row9_col2, #T_6200d_row9_col3, #T_6200d_row9_col4, #T_6200d_row9_col5, #T_6200d_row9_col6, #T_6200d_row10_col0, #T_6200d_row10_col1, #T_6200d_row10_col2, #T_6200d_row10_col3, #T_6200d_row10_col4, #T_6200d_row10_col5, #T_6200d_row10_col6, #T_6200d_row11_col0, #T_6200d_row11_col1, #T_6200d_row11_col2, #T_6200d_row11_col3, #T_6200d_row11_col4, #T_6200d_row11_col5, #T_6200d_row11_col6, #T_6200d_row12_col0, #T_6200d_row12_col1, #T_6200d_row12_col2, #T_6200d_row12_col3, #T_6200d_row12_col4, #T_6200d_row12_col5, #T_6200d_row12_col6, #T_6200d_row13_col0, #T_6200d_row13_col1, #T_6200d_row13_col2, #T_6200d_row13_col3, #T_6200d_row13_col4, #T_6200d_row13_col5, #T_6200d_row13_col6, #T_6200d_row14_col0, #T_6200d_row14_col1, #T_6200d_row14_col2, #T_6200d_row14_col3, #T_6200d_row14_col4, #T_6200d_row14_col5, #T_6200d_row14_col6, #T_6200d_row15_col0, #T_6200d_row15_col1, #T_6200d_row15_col2, #T_6200d_row15_col3, #T_6200d_row15_col4, #T_6200d_row15_col5, #T_6200d_row15_col6, #T_6200d_row16_col0, #T_6200d_row16_col1, #T_6200d_row16_col2, #T_6200d_row16_col3, #T_6200d_row16_col4, #T_6200d_row16_col5, #T_6200d_row16_col6, #T_6200d_row17_col0, #T_6200d_row17_col1, #T_6200d_row17_col2, #T_6200d_row17_col3, #T_6200d_row17_col4, #T_6200d_row17_col5, #T_6200d_row17_col6, #T_6200d_row18_col0, #T_6200d_row18_col1, #T_6200d_row18_col2, #T_6200d_row18_col3, #T_6200d_row18_col4, #T_6200d_row18_col5, #T_6200d_row18_col6, #T_6200d_row19_col0, #T_6200d_row19_col1, #T_6200d_row19_col2, #T_6200d_row19_col3, #T_6200d_row19_col4, #T_6200d_row19_col5, #T_6200d_row19_col6 {
#   text-align: left;
# }
# #T_6200d_row0_col2, #T_6200d_row0_col3, #T_6200d_row0_col4, #T_6200d_row1_col1, #T_6200d_row1_col5, #T_6200d_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6200d_row0_col7, #T_6200d_row1_col7, #T_6200d_row2_col7, #T_6200d_row3_col7, #T_6200d_row4_col7, #T_6200d_row5_col7, #T_6200d_row6_col7, #T_6200d_row7_col7, #T_6200d_row8_col7, #T_6200d_row9_col7, #T_6200d_row10_col7, #T_6200d_row11_col7, #T_6200d_row12_col7, #T_6200d_row13_col7, #T_6200d_row14_col7, #T_6200d_row15_col7, #T_6200d_row16_col7, #T_6200d_row18_col7, #T_6200d_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6200d_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6200d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6200d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6200d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6200d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6200d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6200d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6200d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6200d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6200d_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6200d_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_6200d_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_6200d_row0_col1" class="data row0 col1" >171762.2644</td>
#       <td id="T_6200d_row0_col2" class="data row0 col2" >162348945986.0302</td>
#       <td id="T_6200d_row0_col3" class="data row0 col3" >400549.0667</td>
#       <td id="T_6200d_row0_col4" class="data row0 col4" >0.9403</td>
#       <td id="T_6200d_row0_col5" class="data row0 col5" >0.1119</td>
#       <td id="T_6200d_row0_col6" class="data row0 col6" >0.0817</td>
#       <td id="T_6200d_row0_col7" class="data row0 col7" >10.6860</td>
#     </tr>
#     <tr>
#       <th id="T_6200d_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_6200d_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_6200d_row1_col1" class="data row1 col1" >152010.0763</td>
#       <td id="T_6200d_row1_col2" class="data row1 col2" >163088883440.8048</td>
#       <td id="T_6200d_row1_col3" class="data row1 col3" >402141.0747</td>
#       <td id="T_6200d_row1_col4" class="data row1 col4" >0.9401</td>
#       <td id="T_6200d_row1_col5" class="data row1 col5" >0.1003</td>
#       <td id="T_6200d_row1_col6" class="data row1 col6" >0.0683</td>
#       <td id="T_6200d_row1_col7" class="data row1 col7" >21.6670</td>
#     </tr>
#     <tr>
#       <th id="T_6200d_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_6200d_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6200d_row2_col1" class="data row2 col1" >178061.5281</td>
#       <td id="T_6200d_row2_col2" class="data row2 col2" >181511278592.0000</td>
#       <td id="T_6200d_row2_col3" class="data row2 col3" >423982.3719</td>
#       <td id="T_6200d_row2_col4" class="data row2 col4" >0.9332</td>
#       <td id="T_6200d_row2_col5" class="data row2 col5" >0.1148</td>
#       <td id="T_6200d_row2_col6" class="data row2 col6" >0.0828</td>
#       <td id="T_6200d_row2_col7" class="data row2 col7" >7.5790</td>
#     </tr>
#     <tr>
#       <th id="T_6200d_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_6200d_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6200d_row3_col1" class="data row3 col1" >192273.7216</td>
#       <td id="T_6200d_row3_col2" class="data row3 col2" >182930919416.3643</td>
#       <td id="T_6200d_row3_col3" class="data row3 col3" >425886.7340</td>
#       <td id="T_6200d_row3_col4" class="data row3 col4" >0.9329</td>
#       <td id="T_6200d_row3_col5" class="data row3 col5" >0.1275</td>
#       <td id="T_6200d_row3_col6" class="data row3 col6" >0.0955</td>
#       <td id="T_6200d_row3_col7" class="data row3 col7" >1.3610</td>
#     </tr>
#     <tr>
#       <th id="T_6200d_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_6200d_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_6200d_row4_col1" class="data row4 col1" >167277.6694</td>
#       <td id="T_6200d_row4_col2" class="data row4 col2" >197726167712.4150</td>
#       <td id="T_6200d_row4_col3" class="data row4 col3" >442565.7919</td>
#       <td id="T_6200d_row4_col4" class="data row4 col4" >0.9275</td>
#       <td id="T_6200d_row4_col5" class="data row4 col5" >0.1089</td>
#       <td id="T_6200d_row4_col6" class="data row4 col6" >0.0745</td>
#       <td id="T_6200d_row4_col7" class="data row4 col7" >34.3240</td>
#     </tr>
#     <tr>
#       <th id="T_6200d_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_6200d_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6200d_row5_col1" class="data row5 col1" >2
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %%
catboost = create_model("catboost")
tuned_catboost = tune_model(catboost)
# Out:
# <style type="text/css">
# #T_19bb4_row10_col0, #T_19bb4_row10_col1, #T_19bb4_row10_col2, #T_19bb4_row10_col3, #T_19bb4_row10_col4, #T_19bb4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_19bb4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19bb4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_19bb4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_19bb4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_19bb4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_19bb4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_19bb4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19bb4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19bb4_row0_col0" class="data row0 col0" >178204.1296</td>
#       <td id="T_19bb4_row0_col1" class="data row0 col1" >216110365068.3903</td>
#       <td id="T_19bb4_row0_col2" class="data row0 col2" >464876.7203</td>
#       <td id="T_19bb4_row0_col3" class="data row0 col3" >0.9241</td>
#       <td id="T_19bb4_row0_col4" class="data row0 col4" >0.1132</td>
#       <td id="T_19bb4_row0_col5" class="data row0 col5" >0.0825</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19bb4_row1_col0" class="data row1 col0" >170838.3321</td>
#       <td id="T_19bb4_row1_col1" class="data row1 col1" >143927614578.3099</td>
#       <td id="T_19bb4_row1_col2" class="data row1 col2" >379377.9311</td>
#       <td id="T_19bb4_row1_col3" class="data row1 col3" >0.9467</td>
#       <td id="T_19bb4_row1_col4" class="data row1 col4" >0.1111</td>
#       <td id="T_19bb4_row1_col5" class="data row1 col5" >0.0822</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19bb4_row2_col0" class="data row2 col0" >171274.3047</td>
#       <td id="T_19bb4_row2_col1" class="data row2 col1" >185980748550.7526</td>
#       <td id="T_19bb4_row2_col2" class="data row2 col2" >431254.8534</td>
#       <td id="T_19bb4_row2_col3" class="data row2 col3" >0.9382</td>
#       <td id="T_19bb4_row2_col4" class="data row2 col4" >0.1129</td>
#       <td id="T_19bb4_row2_col5" class="data row2 col5" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19bb4_row3_col0" class="data row3 col0" >171703.8023</td>
#       <td id="T_19bb4_row3_col1" class="data row3 col1" >162332084852.7667</td>
#       <td id="T_19bb4_row3_col2" class="data row3 col2" >402904.5605</td>
#       <td id="T_19bb4_row3_col3" class="data row3 col3" >0.9425</td>
#       <td id="T_19bb4_row3_col4" class="data row3 col4" >0.1090</td>
#       <td id="T_19bb4_row3_col5" class="data row3 col5" >0.0806</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19bb4_row4_col0" class="data row4 col0" >171287.0456</td>
#       <td id="T_19bb4_row4_col1" class="data row4 col1" >175154186211.0347</td>
#       <td id="T_19bb4_row4_col2" class="data row4 col2" >418514.2605</td>
#       <td id="T_19bb4_row4_col3" class="data row4 col3" >0.9225</td>
#       <td id="T_19bb4_row4_col4" class="data row4 col4" >0.1119</td>
#       <td id="T_19bb4_row4_col5" class="data row4 col5" >0.0825</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19bb4_row5_col0" class="data row5 col0" >161644.3998</td>
#       <td id="T_19bb4_row5_col1" class="data row5 col1" >110322399203.5749</td>
#       <td id="T_19bb4_row5_col2" class="data row5 col2" >332148.1585</td>
#       <td id="T_19bb4_row5_col3" class="data row5 col3" >0.9572</td>
#       <td id="T_19bb4_row5_col4" class="data row5 col4" >0.1097</td>
#       <td id="T_19bb4_row5_col5" class="data row5 col5" >0.0805</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_19bb4_row6_col0" class="data row6 col0" >169000.8583</td>
#       <td id="T_19bb4_row6_col1" class="data row6 col1" >116884769004.1683</td>
#       <td id="T_19bb4_row6_col2" class="data row6 col2" >341884.1456</td>
#       <td id="T_19bb4_row6_col3" class="data row6 col3" >0.9603</td>
#       <td id="T_19bb4_row6_col4" class="data row6 col4" >0.1090</td>
#       <td id="T_19bb4_row6_col5" class="data row6 col5" >0.0817</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_19bb4_row7_col0" class="data row7 col0" >174931.0744</td>
#       <td id="T_19bb4_row7_col1" class="data row7 col1" >136021045996.6553</td>
#       <td id="T_19bb4_row7_col2" class="data row7 col2" >368810.3117</td>
#       <td id="T_19bb4_row7_col3" class="data row7 col3" >0.9471</td>
#       <td id="T_19bb4_row7_col4" class="data row7 col4" >0.1123</td>
#       <td id="T_19bb4_row7_col5" class="data row7 col5" >0.0832</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_19bb4_row8_col0" class="data row8 col0" >174459.3076</td>
#       <td id="T_19bb4_row8_col1" class="data row8 col1" >160858820407.6258</td>
#       <td id="T_19bb4_row8_col2" class="data row8 col2" >401072.0888</td>
#       <td id="T_19bb4_row8_col3" class="data row8 col3" >0.9398</td>
#       <td id="T_19bb4_row8_col4" class="data row8 col4" >0.1185</td>
#       <td id="T_19bb4_row8_col5" class="data row8 col5" >0.0839</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_19bb4_row9_col0" class="data row9 col0" >174279.3893</td>
#       <td id="T_19bb4_row9_col1" class="data row9 col1" >215897425987.0226</td>
#       <td id="T_19bb4_row9_col2" class="data row9 col2" >464647.6364</td>
#       <td id="T_19bb4_row9_col3" class="data row9 col3" >0.9244</td>
#       <td id="T_19bb4_row9_col4" class="data row9 col4" >0.1119</td>
#       <td id="T_19bb4_row9_col5" class="data row9 col5" >0.0803</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_19bb4_row10_col0" class="data row10 col0" >171762.2644</td>
#       <td id="T_19bb4_row10_col1" class="data row10 col1" >162348945986.0302</td>
#       <td id="T_19bb4_row10_col2" class="data row10 col2" >400549.0667</td>
#       <td id="T_19bb4_row10_col3" class="data row10 col3" >0.9403</td>
#       <td id="T_19bb4_row10_col4" class="data row10 col4" >0.1119</td>
#       <td id="T_19bb4_row10_col5" class="data row10 col5" >0.0817</td>
#     </tr>
#     <tr>
#       <th id="T_19bb4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_19bb4_row11_col0" class="data row11 col0" >4200.7916</td>
#       <td id="T_19bb4_row11_col1" class="data row11 col1" >35055161742.3309</td>
#       <td id="T_19bb4_row11_col2" class="data row11 col2" >43696.5809</td>
#       <td id="T_19bb4_row11_col3" class="data row11 col3" >0.0127</td>
#       <td id="T_19bb4_row11_col4" class="data row11 col4" >0.0026</td>
#       <td id="T_19bb4_row11_col5" class="data row11 col5" >0.0013</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_f2d99_row10_col0, #T_f2d99_row10_col1, #T_f2d99_row10_col2, #T_f2d99_row10_col3, #T_f2d99_row10_col4, #T_f2d99_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f2d99" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2d99_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f2d99_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f2d99_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f2d99_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f2d99_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f2d99_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2d99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2d99_row0_col0" class="data row0 col0" >192345.3457</td>
#       <td id="T_f2d99_row0_col1" class="data row0 col1" >236167784565.9542</td>
#       <td id="T_f2d99_row0_col2" class="data row0 col2" >485970.9709</td>
#       <td id="T_f2d99_row0_col3" class="data row0 col3" >0.9170</td>
#       <td id="T_f2d99_row0_col4" class="data row0 col4" >0.1208</td>
#       <td id="T_f2d99_row0_col5" class="data row0 col5" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2d99_row1_col0" class="data row1 col0" >183263.8250</td>
#       <td id="T_f2d99_row1_col1" class="data row1 col1" >162520939876.8749</td>
#       <td id="T_f2d99_row1_col2" class="data row1 col2" >403138.8593</td>
#       <td id="T_f2d99_row1_col3" class="data row1 col3" >0.9398</td>
#       <td id="T_f2d99_row1_col4" class="data row1 col4" >0.1185</td>
#       <td id="T_f2d99_row1_col5" class="data row1 col5" >0.0889</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2d99_row2_col0" class="data row2 col0" >180377.5845</td>
#       <td id="T_f2d99_row2_col1" class="data row2 col1" >200988296211.7058</td>
#       <td id="T_f2d99_row2_col2" class="data row2 col2" >448317.1826</td>
#       <td id="T_f2d99_row2_col3" class="data row2 col3" >0.9332</td>
#       <td id="T_f2d99_row2_col4" class="data row2 col4" >0.1185</td>
#       <td id="T_f2d99_row2_col5" class="data row2 col5" >0.0848</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f2d99_row3_col0" class="data row3 col0" >180412.2316</td>
#       <td id="T_f2d99_row3_col1" class="data row3 col1" >190649841481.3800</td>
#       <td id="T_f2d99_row3_col2" class="data row3 col2" >436634.6774</td>
#       <td id="T_f2d99_row3_col3" class="data row3 col3" >0.9325</td>
#       <td id="T_f2d99_row3_col4" class="data row3 col4" >0.1140</td>
#       <td id="T_f2d99_row3_col5" class="data row3 col5" >0.0859</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f2d99_row4_col0" class="data row4 col0" >182209.3682</td>
#       <td id="T_f2d99_row4_col1" class="data row4 col1" >175652306850.0113</td>
#       <td id="T_f2d99_row4_col2" class="data row4 col2" >419108.9439</td>
#       <td id="T_f2d99_row4_col3" class="data row4 col3" >0.9223</td>
#       <td id="T_f2d99_row4_col4" class="data row4 col4" >0.1186</td>
#       <td id="T_f2d99_row4_col5" class="data row4 col5" >0.0881</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f2d99_row5_col0" class="data row5 col0" >174012.2815</td>
#       <td id="T_f2d99_row5_col1" class="data row5 col1" >116021938433.8438</td>
#       <td id="T_f2d99_row5_col2" class="data row5 col2" >340619.9325</td>
#       <td id="T_f2d99_row5_col3" class="data row5 col3" >0.9550</td>
#       <td id="T_f2d99_row5_col4" class="data row5 col4" >0.1176</td>
#       <td id="T_f2d99_row5_col5" class="data row5 col5" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f2d99_row6_col0" class="data row6 col0" >185251.3630</td>
#       <td id="T_f2d99_row6_col1" class="data row6 col1" >143972766389.7194</td>
#       <td id="T_f2d99_row6_col2" class="data row6 col2" >379437.4341</td>
#       <td id="T_f2d99_row6_col3" class="data row6 col3" >0.9511</td>
#       <td id="T_f2d99_row6_col4" class="data row6 col4" >0.1203</td>
#       <td id="T_f2d99_row6_col5" class="data row6 col5" >0.0914</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f2d99_row7_col0" class="data row7 col0" >184299.0990</td>
#       <td id="T_f2d99_row7_col1" class="data row7 col1" >144588104205.0522</td>
#       <td id="T_f2d99_row7_col2" class="data row7 col2" >380247.4250</td>
#       <td id="T_f2d99_row7_col3" class="data row7 col3" >0.9438</td>
#       <td id="T_f2d99_row7_col4" class="data row7 col4" >0.1185</td>
#       <td id="T_f2d99_row7_col5" class="data row7 col5" >0.0888</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f2d99_row8_col0" class="data row8 col0" >185754.4203</td>
#       <td id="T_f2d99_row8_col1" class="data row8 col1" >185807641481.5186</td>
#       <td id="T_f2d99_row8_col2" class="data row8 col2" >431054.1051</td>
#       <td id="T_f2d99_row8_col3" class="data row8 col3" >0.9304</td>
#       <td id="T_f2d99_row8_col4" class="data row8 col4" >0.1239</td>
#       <td id="T_f2d99_row8_col5" class="data row8 col5" >0.0895</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f2d99_row9_col0" class="data row9 col0" >183938.7538</td>
#       <td id="T_f2d99_row9_col1" class="data row9 col1" >217564081042.4059</td>
#       <td id="T_f2d99_row9_col2" class="data row9 col2" >466437.6497</td>
#       <td id="T_f2d99_row9_col3" class="data row9 col3" >0.9238</td>
#       <td id="T_f2d99_row9_col4" class="data row9 col4" >0.1186</td>
#       <td id="T_f2d99_row9_col5" class="data row9 col5" >0.0865</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f2d99_row10_col0" class="data row10 col0" >183186.4273</td>
#       <td id="T_f2d99_row10_col1" class="data row10 col1" >177393370053.8466</td>
#       <td id="T_f2d99_row10_col2" class="data row10 col2" >419096.7180</td>
#       <td id="T_f2d99_row10_col3" class="data row10 col3" >0.9349</td>
#       <td id="T_f2d99_row10_col4" class="data row10 col4" >0.1190</td>
#       <td id="T_f2d99_row10_col5" class="data row10 col5" >0.0882</td>
#     </tr>
#     <tr>
#       <th id="T_f2d99_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f2d99_row11_col0" class="data row11 col0" >4441.3930</td>
#       <td id="T_f2d99_row11_col1" class="data row11 col1" >34720552526.6402</td>
#       <td id="T_f2d99_row11_col2" class="data row11 col2" >41848.6676</td>
#       <td id="T_f2d99_row11_col3" class="data row11 col3" >0.0118</td>
#       <td id="T_f2d99_row11_col4" class="data row11 col4" >0.0024</td>
#       <td id="T_f2d99_row11_col5" class="data row11 col5" >0.0019</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
xgboost = create_model("xgboost")
lightgbm = create_model("lightgbm")
tuned_xgboost = tune_model(xgboost)
tuned_lightgbm = tune_model(lightgbm)
# Out:
# <style type="text/css">
# #T_7ef28_row10_col0, #T_7ef28_row10_col1, #T_7ef28_row10_col2, #T_7ef28_row10_col3, #T_7ef28_row10_col4, #T_7ef28_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7ef28" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ef28_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7ef28_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7ef28_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7ef28_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7ef28_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7ef28_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ef28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ef28_row0_col0" class="data row0 col0" >185341.5000</td>
#       <td id="T_7ef28_row0_col1" class="data row0 col1" >213245067264.0000</td>
#       <td id="T_7ef28_row0_col2" class="data row0 col2" >461784.6562</td>
#       <td id="T_7ef28_row0_col3" class="data row0 col3" >0.9251</td>
#       <td id="T_7ef28_row0_col4" class="data row0 col4" >0.1175</td>
#       <td id="T_7ef28_row0_col5" class="data row0 col5" >0.0858</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ef28_row1_col0" class="data row1 col0" >178394.0625</td>
#       <td id="T_7ef28_row1_col1" class="data row1 col1" >154918944768.0000</td>
#       <td id="T_7ef28_row1_col2" class="data row1 col2" >393597.4375</td>
#       <td id="T_7ef28_row1_col3" class="data row1 col3" >0.9426</td>
#       <td id="T_7ef28_row1_col4" class="data row1 col4" >0.1142</td>
#       <td id="T_7ef28_row1_col5" class="data row1 col5" >0.0836</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ef28_row2_col0" class="data row2 col0" >180954.5312</td>
#       <td id="T_7ef28_row2_col1" class="data row2 col1" >216079974400.0000</td>
#       <td id="T_7ef28_row2_col2" class="data row2 col2" >464844.0312</td>
#       <td id="T_7ef28_row2_col3" class="data row2 col3" >0.9282</td>
#       <td id="T_7ef28_row2_col4" class="data row2 col4" >0.1168</td>
#       <td id="T_7ef28_row2_col5" class="data row2 col5" >0.0814</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ef28_row3_col0" class="data row3 col0" >179640.2344</td>
#       <td id="T_7ef28_row3_col1" class="data row3 col1" >184172150784.0000</td>
#       <td id="T_7ef28_row3_col2" class="data row3 col2" >429152.8438</td>
#       <td id="T_7ef28_row3_col3" class="data row3 col3" >0.9348</td>
#       <td id="T_7ef28_row3_col4" class="data row3 col4" >0.1128</td>
#       <td id="T_7ef28_row3_col5" class="data row3 col5" >0.0826</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ef28_row4_col0" class="data row4 col0" >176037.9375</td>
#       <td id="T_7ef28_row4_col1" class="data row4 col1" >210283560960.0000</td>
#       <td id="T_7ef28_row4_col2" class="data row4 col2" >458566.8438</td>
#       <td id="T_7ef28_row4_col3" class="data row4 col3" >0.9070</td>
#       <td id="T_7ef28_row4_col4" class="data row4 col4" >0.1154</td>
#       <td id="T_7ef28_row4_col5" class="data row4 col5" >0.0836</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ef28_row5_col0" class="data row5 col0" >166728.5156</td>
#       <td id="T_7ef28_row5_col1" class="data row5 col1" >118588268544.0000</td>
#       <td id="T_7ef28_row5_col2" class="data row5 col2" >344366.4688</td>
#       <td id="T_7ef28_row5_col3" class="data row5 col3" >0.9540</td>
#       <td id="T_7ef28_row5_col4" class="data row5 col4" >0.1119</td>
#       <td id="T_7ef28_row5_col5" class="data row5 col5" >0.0806</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ef28_row6_col0" class="data row6 col0" >180029.0938</td>
#       <td id="T_7ef28_row6_col1" class="data row6 col1" >167187218432.0000</td>
#       <td id="T_7ef28_row6_col2" class="data row6 col2" >408885.3438</td>
#       <td id="T_7ef28_row6_col3" class="data row6 col3" >0.9432</td>
#       <td id="T_7ef28_row6_col4" class="data row6 col4" >0.1124</td>
#       <td id="T_7ef28_row6_col5" class="data row6 col5" >0.0826</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7ef28_row7_col0" class="data row7 col0" >178729.3438</td>
#       <td id="T_7ef28_row7_col1" class="data row7 col1" >156548628480.0000</td>
#       <td id="T_7ef28_row7_col2" class="data row7 col2" >395662.2812</td>
#       <td id="T_7ef28_row7_col3" class="data row7 col3" >0.9392</td>
#       <td id="T_7ef28_row7_col4" class="data row7 col4" >0.1131</td>
#       <td id="T_7ef28_row7_col5" class="data row7 col5" >0.0832</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7ef28_row8_col0" class="data row8 col0" >175300.5938</td>
#       <td id="T_7ef28_row8_col1" class="data row8 col1" >156215525376.0000</td>
#       <td id="T_7ef28_row8_col2" class="data row8 col2" >395241.0938</td>
#       <td id="T_7ef28_row8_col3" class="data row8 col3" >0.9415</td>
#       <td id="T_7ef28_row8_col4" class="data row8 col4" >0.1191</td>
#       <td id="T_7ef28_row8_col5" class="data row8 col5" >0.0836</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7ef28_row9_col0" class="data row9 col0" >179459.4688</td>
#       <td id="T_7ef28_row9_col1" class="data row9 col1" >237873446912.0000</td>
#       <td id="T_7ef28_row9_col2" class="data row9 col2" >487722.7188</td>
#       <td id="T_7ef28_row9_col3" class="data row9 col3" >0.9167</td>
#       <td id="T_7ef28_row9_col4" class="data row9 col4" >0.1151</td>
#       <td id="T_7ef28_row9_col5" class="data row9 col5" >0.0811</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7ef28_row10_col0" class="data row10 col0" >178061.5281</td>
#       <td id="T_7ef28_row10_col1" class="data row10 col1" >181511278592.0000</td>
#       <td id="T_7ef28_row10_col2" class="data row10 col2" >423982.3719</td>
#       <td id="T_7ef28_row10_col3" class="data row10 col3" >0.9332</td>
#       <td id="T_7ef28_row10_col4" class="data row10 col4" >0.1148</td>
#       <td id="T_7ef28_row10_col5" class="data row10 col5" >0.0828</td>
#     </tr>
#     <tr>
#       <th id="T_7ef28_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7ef28_row11_col0" class="data row11 col0" >4586.9023</td>
#       <td id="T_7ef28_row11_col1" class="data row11 col1" >35140136179.4704</td>
#       <td id="T_7ef28_row11_col2" class="data row11 col2" >41835.7315</td>
#       <td id="T_7ef28_row11_col3" class="data row11 col3" >0.0133</td>
#       <td id="T_7ef28_row11_col4" class="data row11 col4" >0.0023</td>
#       <td id="T_7ef28_row11_col5" class="data row11 col5" >0.0014</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_70123_row10_col0, #T_70123_row10_col1, #T_70123_row10_col2, #T_70123_row10_col3, #T_70123_row10_col4, #T_70123_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_70123" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70123_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_70123_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_70123_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_70123_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_70123_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_70123_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70123_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70123_row0_col0" class="data row0 col0" >198501.1507</td>
#       <td id="T_70123_row0_col1" class="data row0 col1" >222044560588.8475</td>
#       <td id="T_70123_row0_col2" class="data row0 col2" >471216.0445</td>
#       <td id="T_70123_row0_col3" class="data row0 col3" >0.9220</td>
#       <td id="T_70123_row0_col4" class="data row0 col4" >0.1274</td>
#       <td id="T_70123_row0_col5" class="data row0 col5" >0.0965</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70123_row1_col0" class="data row1 col0" >189154.3619</td>
#       <td id="T_70123_row1_col1" class="data row1 col1" >156015537063.5287</td>
#       <td id="T_70123_row1_col2" class="data row1 col2" >394988.0214</td>
#       <td id="T_70123_row1_col3" class="data row1 col3" >0.9422</td>
#       <td id="T_70123_row1_col4" class="data row1 col4" >0.1259</td>
#       <td id="T_70123_row1_col5" class="data row1 col5" >0.0952</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_70123_row2_col0" class="data row2 col0" >191036.5637</td>
#       <td id="T_70123_row2_col1" class="data row2 col1" >218481607378.6800</td>
#       <td id="T_70123_row2_col2" class="data row2 col2" >467420.1615</td>
#       <td id="T_70123_row2_col3" class="data row2 col3" >0.9274</td>
#       <td id="T_70123_row2_col4" class="data row2 col4" >0.1275</td>
#       <td id="T_70123_row2_col5" class="data row2 col5" >0.0924</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_70123_row3_col0" class="data row3 col0" >190691.1966</td>
#       <td id="T_70123_row3_col1" class="data row3 col1" >179630451872.8750</td>
#       <td id="T_70123_row3_col2" class="data row3 col2" >423828.3283</td>
#       <td id="T_70123_row3_col3" class="data row3 col3" >0.9364</td>
#       <td id="T_70123_row3_col4" class="data row3 col4" >0.1247</td>
#       <td id="T_70123_row3_col5" class="data row3 col5" >0.0952</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_70123_row4_col0" class="data row4 col0" >190083.5626</td>
#       <td id="T_70123_row4_col1" class="data row4 col1" >181205707024.2294</td>
#       <td id="T_70123_row4_col2" class="data row4 col2" >425682.6365</td>
#       <td id="T_70123_row4_col3" class="data row4 col3" >0.9198</td>
#       <td id="T_70123_row4_col4" class="data row4 col4" >0.1285</td>
#       <td id="T_70123_row4_col5" class="data row4 col5" >0.0958</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_70123_row5_col0" class="data row5 col0" >183768.7645</td>
#       <td id="T_70123_row5_col1" class="data row5 col1" >130916661743.6878</td>
#       <td id="T_70123_row5_col2" class="data row5 col2" >361824.0757</td>
#       <td id="T_70123_row5_col3" class="data row5 col3" >0.9492</td>
#       <td id="T_70123_row5_col4" class="data row5 col4" >0.1264</td>
#       <td id="T_70123_row5_col5" class="data row5 col5" >0.0949</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_70123_row6_col0" class="data row6 col0" >192314.8197</td>
#       <td id="T_70123_row6_col1" class="data row6 col1" >151066279021.5462</td>
#       <td id="T_70123_row6_col2" class="data row6 col2" >388672.4572</td>
#       <td id="T_70123_row6_col3" class="data row6 col3" >0.9487</td>
#       <td id="T_70123_row6_col4" class="data row6 col4" >0.1258</td>
#       <td id="T_70123_row6_col5" class="data row6 col5" >0.0957</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_70123_row7_col0" class="data row7 col0" >196045.2490</td>
#       <td id="T_70123_row7_col1" class="data row7 col1" >158379219197.4160</td>
#       <td id="T_70123_row7_col2" class="data row7 col2" >397968.8671</td>
#       <td id="T_70123_row7_col3" class="data row7 col3" >0.9385</td>
#       <td id="T_70123_row7_col4" class="data row7 col4" >0.1289</td>
#       <td id="T_70123_row7_col5" class="data row7 col5" >0.0976</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_70123_row8_col0" class="data row8 col0" >196717.9141</td>
#       <td id="T_70123_row8_col1" class="data row8 col1" >189091543659.9127</td>
#       <td id="T_70123_row8_col2" class="data row8 col2" >434846.5749</td>
#       <td id="T_70123_row8_col3" class="data row8 col3" >0.9292</td>
#       <td id="T_70123_row8_col4" class="data row8 col4" >0.1332</td>
#       <td id="T_70123_row8_col5" class="data row8 col5" >0.0981</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_70123_row9_col0" class="data row9 col0" >194423.6334</td>
#       <td id="T_70123_row9_col1" class="data row9 col1" >242477626612.9196</td>
#       <td id="T_70123_row9_col2" class="data row9 col2" >492420.1728</td>
#       <td id="T_70123_row9_col3" class="data row9 col3" >0.9151</td>
#       <td id="T_70123_row9_col4" class="data row9 col4" >0.1272</td>
#       <td id="T_70123_row9_col5" class="data row9 col5" >0.0939</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_70123_row10_col0" class="data row10 col0" >192273.7216</td>
#       <td id="T_70123_row10_col1" class="data row10 col1" >182930919416.3643</td>
#       <td id="T_70123_row10_col2" class="data row10 col2" >425886.7340</td>
#       <td id="T_70123_row10_col3" class="data row10 col3" >0.9329</td>
#       <td id="T_70123_row10_col4" class="data row10 col4" >0.1275</td>
#       <td id="T_70123_row10_col5" class="data row10 col5" >0.0955</td>
#     </tr>
#     <tr>
#       <th id="T_70123_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_70123_row11_col0" class="data row11 col0" >4102.1505</td>
#       <td id="T_70123_row11_col1" class="data row11 col1" >33822216829.7125</td>
#       <td id="T_70123_row11_col2" class="data row11 col2" >39387.9324</td>
#       <td id="T_70123_row11_col3" class="data row11 col3" >0.0114</td>
#       <td id="T_70123_row11_col4" class="data row11 col4" >0.0022</td>
#       <td id="T_70123_row11_col5" class="data row11 col5" >0.0016</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_f5a75_row10_col0, #T_f5a75_row10_col1, #T_f5a75_row10_col2, #T_f5a75_row10_col3, #T_f5a75_row10_col4, #T_f5a75_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f5a75" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5a75_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f5a75_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f5a75_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f5a75_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f5a75_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f5a75_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5a75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5a75_row0_col0" class="data row0 col0" >170446.0156</td>
#       <td id="T_f5a75_row0_col1" class="data row0 col1" >207524593664.0000</td>
#       <td id="T_f5a75_row0_col2" class="data row0 col2" >455548.6875</td>
#       <td id="T_f5a75_row0_col3" class="data row0 col3" >0.9271</td>
#       <td id="T_f5a75_row0_col4" class="data row0 col4" >0.1073</td>
#       <td id="T_f5a75_row0_col5" class="data row0 col5" >0.0761</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f5a75_row1_col0" class="data row1 col0" >160728.9062</td>
#       <td id="T_f5a75_row1_col1" class="data row1 col1" >144275013632.0000</td>
#       <td id="T_f5a75_row1_col2" class="data row1 col2" >379835.5000</td>
#       <td id="T_f5a75_row1_col3" class="data row1 col3" >0.9466</td>
#       <td id="T_f5a75_row1_col4" class="data row1 col4" >0.1046</td>
#       <td id="T_f5a75_row1_col5" class="data row1 col5" >0.0744</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f5a75_row2_col0" class="data row2 col0" >170274.6562</td>
#       <td id="T_f5a75_row2_col1" class="data row2 col1" >224625000448.0000</td>
#       <td id="T_f5a75_row2_col2" class="data row2 col2" >473946.1875</td>
#       <td id="T_f5a75_row2_col3" class="data row2 col3" >0.9254</td>
#       <td id="T_f5a75_row2_col4" class="data row2 col4" >0.1093</td>
#       <td id="T_f5a75_row2_col5" class="data row2 col5" >0.0743</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f5a75_row3_col0" class="data row3 col0" >164277.0469</td>
#       <td id="T_f5a75_row3_col1" class="data row3 col1" >144714399744.0000</td>
#       <td id="T_f5a75_row3_col2" class="data row3 col2" >380413.4688</td>
#       <td id="T_f5a75_row3_col3" class="data row3 col3" >0.9487</td>
#       <td id="T_f5a75_row3_col4" class="data row3 col4" >0.1027</td>
#       <td id="T_f5a75_row3_col5" class="data row3 col5" >0.0741</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f5a75_row4_col0" class="data row4 col0" >159820.7031</td>
#       <td id="T_f5a75_row4_col1" class="data row4 col1" >174770307072.0000</td>
#       <td id="T_f5a75_row4_col2" class="data row4 col2" >418055.3750</td>
#       <td id="T_f5a75_row4_col3" class="data row4 col3" >0.9227</td>
#       <td id="T_f5a75_row4_col4" class="data row4 col4" >0.1043</td>
#       <td id="T_f5a75_row4_col5" class="data row4 col5" >0.0744</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f5a75_row5_col0" class="data row5 col0" >156446.3281</td>
#       <td id="T_f5a75_row5_col1" class="data row5 col1" >114346614784.0000</td>
#       <td id="T_f5a75_row5_col2" class="data row5 col2" >338151.7500</td>
#       <td id="T_f5a75_row5_col3" class="data row5 col3" >0.9557</td>
#       <td id="T_f5a75_row5_col4" class="data row5 col4" >0.1065</td>
#       <td id="T_f5a75_row5_col5" class="data row5 col5" >0.0749</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f5a75_row6_col0" class="data row6 col0" >164380.7969</td>
#       <td id="T_f5a75_row6_col1" class="data row6 col1" >132803936256.0000</td>
#       <td id="T_f5a75_row6_col2" class="data row6 col2" >364422.7500</td>
#       <td id="T_f5a75_row6_col3" class="data row6 col3" >0.9549</td>
#       <td id="T_f5a75_row6_col4" class="data row6 col4" >0.1037</td>
#       <td id="T_f5a75_row6_col5" class="data row6 col5" >0.0753</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f5a75_row7_col0" class="data row7 col0" >166388.5938</td>
#       <td id="T_f5a75_row7_col1" class="data row7 col1" >150291054592.0000</td>
#       <td id="T_f5a75_row7_col2" class="data row7 col2" >387673.9062</td>
#       <td id="T_f5a75_row7_col3" class="data row7 col3" >0.9416</td>
#       <td id="T_f5a75_row7_col4" class="data row7 col4" >0.1064</td>
#       <td id="T_f5a75_row7_col5" class="data row7 col5" >0.0756</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f5a75_row8_col0" class="data row8 col0" >170602.4219</td>
#       <td id="T_f5a75_row8_col1" class="data row8 col1" >181417541632.0000</td>
#       <td id="T_f5a75_row8_col2" class="data row8 col2" >425931.3750</td>
#       <td id="T_f5a75_row8_col3" class="data row8 col3" >0.9321</td>
#       <td id="T_f5a75_row8_col4" class="data row8 col4" >0.1142</td>
#       <td id="T_f5a75_row8_col5" class="data row8 col5" >0.0778</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f5a75_row9_col0" class="data row9 col0" >162489.0000</td>
#       <td id="T_f5a75_row9_col1" class="data row9 col1" >208706977792.0000</td>
#       <td id="T_f5a75_row9_col2" class="data row9 col2" >456844.5938</td>
#       <td id="T_f5a75_row9_col3" class="data row9 col3" >0.9269</td>
#       <td id="T_f5a75_row9_col4" class="data row9 col4" >0.1067</td>
#       <td id="T_f5a75_row9_col5" class="data row9 col5" >0.0737</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f5a75_row10_col0" class="data row10 col0" >164585.4469</td>
#       <td id="T_f5a75_row10_col1" class="data row10 col1" >168347543961.6000</td>
#       <td id="T_f5a75_row10_col2" class="data row10 col2" >408082.3594</td>
#       <td id="T_f5a75_row10_col3" class="data row10 col3" >0.9382</td>
#       <td id="T_f5a75_row10_col4" class="data row10 col4" >0.1066</td>
#       <td id="T_f5a75_row10_col5" class="data row10 col5" >0.0751</td>
#     </tr>
#     <tr>
#       <th id="T_f5a75_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f5a75_row11_col0" class="data row11 col0" >4631.6490</td>
#       <td id="T_f5a75_row11_col1" class="data row11 col1" >34909098222.8954</td>
#       <td id="T_f5a75_row11_col2" class="data row11 col2" >42618.4341</td>
#       <td id="T_f5a75_row11_col3" class="data row11 col3" >0.0121</td>
#       <td id="T_f5a75_row11_col4" class="data row11 col4" >0.0031</td>
#       <td id="T_f5a75_row11_col5" class="data row11 col5" >0.0012</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_2261d_row10_col0, #T_2261d_row10_col1, #T_2261d_row10_col2, #T_2261d_row10_col3, #T_2261d_row10_col4, #T_2261d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2261d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2261d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2261d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2261d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2261d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2261d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2261d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2261d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2261d_row0_col0" class="data row0 col0" >187917.0450</td>
#       <td id="T_2261d_row0_col1" class="data row0 col1" >221928217924.5422</td>
#       <td id="T_2261d_row0_col2" class="data row0 col2" >471092.5789</td>
#       <td id="T_2261d_row0_col3" class="data row0 col3" >0.9220</td>
#       <td id="T_2261d_row0_col4" class="data row0 col4" >0.1174</td>
#       <td id="T_2261d_row0_col5" class="data row0 col5" >0.0862</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2261d_row1_col0" class="data row1 col0" >176915.0753</td>
#       <td id="T_2261d_row1_col1" class="data row1 col1" >147379665926.8586</td>
#       <td id="T_2261d_row1_col2" class="data row1 col2" >383900.5938</td>
#       <td id="T_2261d_row1_col3" class="data row1 col3" >0.9454</td>
#       <td id="T_2261d_row1_col4" class="data row1 col4" >0.1157</td>
#       <td id="T_2261d_row1_col5" class="data row1 col5" >0.0858</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2261d_row2_col0" class="data row2 col0" >181564.5634</td>
#       <td id="T_2261d_row2_col1" class="data row2 col1" >234204519536.5110</td>
#       <td id="T_2261d_row2_col2" class="data row2 col2" >483946.8148</td>
#       <td id="T_2261d_row2_col3" class="data row2 col3" >0.9222</td>
#       <td id="T_2261d_row2_col4" class="data row2 col4" >0.1195</td>
#       <td id="T_2261d_row2_col5" class="data row2 col5" >0.0833</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2261d_row3_col0" class="data row3 col0" >180133.9271</td>
#       <td id="T_2261d_row3_col1" class="data row3 col1" >219916392398.8154</td>
#       <td id="T_2261d_row3_col2" class="data row3 col2" >468952.4415</td>
#       <td id="T_2261d_row3_col3" class="data row3 col3" >0.9221</td>
#       <td id="T_2261d_row3_col4" class="data row3 col4" >0.1127</td>
#       <td id="T_2261d_row3_col5" class="data row3 col5" >0.0831</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2261d_row4_col0" class="data row4 col0" >177173.1875</td>
#       <td id="T_2261d_row4_col1" class="data row4 col1" >161466233144.1518</td>
#       <td id="T_2261d_row4_col2" class="data row4 col2" >401828.6117</td>
#       <td id="T_2261d_row4_col3" class="data row4 col3" >0.9286</td>
#       <td id="T_2261d_row4_col4" class="data row4 col4" >0.1144</td>
#       <td id="T_2261d_row4_col5" class="data row4 col5" >0.0841</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2261d_row5_col0" class="data row5 col0" >175555.1252</td>
#       <td id="T_2261d_row5_col1" class="data row5 col1" >157148732550.5052</td>
#       <td id="T_2261d_row5_col2" class="data row5 col2" >396419.8942</td>
#       <td id="T_2261d_row5_col3" class="data row5 col3" >0.9391</td>
#       <td id="T_2261d_row5_col4" class="data row5 col4" >0.1184</td>
#       <td id="T_2261d_row5_col5" class="data row5 col5" >0.0849</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2261d_row6_col0" class="data row6 col0" >182375.8239</td>
#       <td id="T_2261d_row6_col1" class="data row6 col1" >147082663999.1856</td>
#       <td id="T_2261d_row6_col2" class="data row6 col2" >383513.5773</td>
#       <td id="T_2261d_row6_col3" class="data row6 col3" >0.9500</td>
#       <td id="T_2261d_row6_col4" class="data row6 col4" >0.1165</td>
#       <td id="T_2261d_row6_col5" class="data row6 col5" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2261d_row7_col0" class="data row7 col0" >183934.8213</td>
#       <td id="T_2261d_row7_col1" class="data row7 col1" >160614684952.4900</td>
#       <td id="T_2261d_row7_col2" class="data row7 col2" >400767.6196</td>
#       <td id="T_2261d_row7_col3" class="data row7 col3" >0.9376</td>
#       <td id="T_2261d_row7_col4" class="data row7 col4" >0.1188</td>
#       <td id="T_2261d_row7_col5" class="data row7 col5" >0.0867</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2261d_row8_col0" class="data row8 col0" >184806.2291</td>
#       <td id="T_2261d_row8_col1" class="data row8 col1" >190267971026.3935</td>
#       <td id="T_2261d_row8_col2" class="data row8 col2" >436197.1699</td>
#       <td id="T_2261d_row8_col3" class="data row8 col3" >0.9287</td>
#       <td id="T_2261d_row8_col4" class="data row8 col4" >0.1243</td>
#       <td id="T_2261d_row8_col5" class="data row8 col5" >0.0878</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2261d_row9_col0" class="data row9 col0" >179954.5514</td>
#       <td id="T_2261d_row9_col1" class="data row9 col1" >220396018681.1296</td>
#       <td id="T_2261d_row9_col2" class="data row9 col2" >469463.5435</td>
#       <td id="T_2261d_row9_col3" class="data row9 col3" >0.9229</td>
#       <td id="T_2261d_row9_col4" class="data row9 col4" >0.1167</td>
#       <td id="T_2261d_row9_col5" class="data row9 col5" >0.0835</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2261d_row10_col0" class="data row10 col0" >181033.0349</td>
#       <td id="T_2261d_row10_col1" class="data row10 col1" >186040510014.0583</td>
#       <td id="T_2261d_row10_col2" class="data row10 col2" >429608.2845</td>
#       <td id="T_2261d_row10_col3" class="data row10 col3" >0.9319</td>
#       <td id="T_2261d_row10_col4" class="data row10 col4" >0.1174</td>
#       <td id="T_2261d_row10_col5" class="data row10 col5" >0.0851</td>
#     </tr>
#     <tr>
#       <th id="T_2261d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2261d_row11_col0" class="data row11 col0" >3687.3783</td>
#       <td id="T_2261d_row11_col1" class="data row11 col1" >33242930530.3761</td>
#       <td id="T_2261d_row11_col2" class="data row11 col2" >38434.7743</td>
#       <td id="T_2261d_row11_col3" class="data row11 col3" >0.0099</td>
#       <td id="T_2261d_row11_col4" class="data row11 col4" >0.0030</td>
#       <td id="T_2261d_row11_col5" class="data row11 col5" >0.0015</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
bagged_catboost = ensemble_model(catboost, method = 'Bagging')
# Out:
# <style type="text/css">
# #T_9fd26_row10_col0, #T_9fd26_row10_col1, #T_9fd26_row10_col2, #T_9fd26_row10_col3, #T_9fd26_row10_col4, #T_9fd26_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9fd26" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fd26_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9fd26_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9fd26_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9fd26_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9fd26_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9fd26_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fd26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fd26_row0_col0" class="data row0 col0" >174583.0193</td>
#       <td id="T_9fd26_row0_col1" class="data row0 col1" >210600668534.5772</td>
#       <td id="T_9fd26_row0_col2" class="data row0 col2" >458912.4846</td>
#       <td id="T_9fd26_row0_col3" class="data row0 col3" >0.9260</td>
#       <td id="T_9fd26_row0_col4" class="data row0 col4" >0.1116</td>
#       <td id="T_9fd26_row0_col5" class="data row0 col5" >0.0806</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9fd26_row1_col0" class="data row1 col0" >167942.2464</td>
#       <td id="T_9fd26_row1_col1" class="data row1 col1" >149495130793.9588</td>
#       <td id="T_9fd26_row1_col2" class="data row1 col2" >386646.0019</td>
#       <td id="T_9fd26_row1_col3" class="data row1 col3" >0.9447</td>
#       <td id="T_9fd26_row1_col4" class="data row1 col4" >0.1089</td>
#       <td id="T_9fd26_row1_col5" class="data row1 col5" >0.0798</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9fd26_row2_col0" class="data row2 col0" >170519.5692</td>
#       <td id="T_9fd26_row2_col1" class="data row2 col1" >204494109573.0965</td>
#       <td id="T_9fd26_row2_col2" class="data row2 col2" >452210.2493</td>
#       <td id="T_9fd26_row2_col3" class="data row2 col3" >0.9321</td>
#       <td id="T_9fd26_row2_col4" class="data row2 col4" >0.1118</td>
#       <td id="T_9fd26_row2_col5" class="data row2 col5" >0.0782</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9fd26_row3_col0" class="data row3 col0" >167981.2767</td>
#       <td id="T_9fd26_row3_col1" class="data row3 col1" >171041933638.7794</td>
#       <td id="T_9fd26_row3_col2" class="data row3 col2" >413572.1626</td>
#       <td id="T_9fd26_row3_col3" class="data row3 col3" >0.9394</td>
#       <td id="T_9fd26_row3_col4" class="data row3 col4" >0.1061</td>
#       <td id="T_9fd26_row3_col5" class="data row3 col5" >0.0778</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9fd26_row4_col0" class="data row4 col0" >165161.1003</td>
#       <td id="T_9fd26_row4_col1" class="data row4 col1" >149888904159.9075</td>
#       <td id="T_9fd26_row4_col2" class="data row4 col2" >387154.8839</td>
#       <td id="T_9fd26_row4_col3" class="data row4 col3" >0.9337</td>
#       <td id="T_9fd26_row4_col4" class="data row4 col4" >0.1087</td>
#       <td id="T_9fd26_row4_col5" class="data row4 col5" >0.0797</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9fd26_row5_col0" class="data row5 col0" >158070.2659</td>
#       <td id="T_9fd26_row5_col1" class="data row5 col1" >106450366368.1871</td>
#       <td id="T_9fd26_row5_col2" class="data row5 col2" >326267.3235</td>
#       <td id="T_9fd26_row5_col3" class="data row5 col3" >0.9587</td>
#       <td id="T_9fd26_row5_col4" class="data row5 col4" >0.1072</td>
#       <td id="T_9fd26_row5_col5" class="data row5 col5" >0.0779</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9fd26_row6_col0" class="data row6 col0" >167991.6525</td>
#       <td id="T_9fd26_row6_col1" class="data row6 col1" >122859951589.8624</td>
#       <td id="T_9fd26_row6_col2" class="data row6 col2" >350513.8394</td>
#       <td id="T_9fd26_row6_col3" class="data row6 col3" >0.9583</td>
#       <td id="T_9fd26_row6_col4" class="data row6 col4" >0.1079</td>
#       <td id="T_9fd26_row6_col5" class="data row6 col5" >0.0801</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9fd26_row7_col0" class="data row7 col0" >171777.7078</td>
#       <td id="T_9fd26_row7_col1" class="data row7 col1" >135182336916.2988</td>
#       <td id="T_9fd26_row7_col2" class="data row7 col2" >367671.5068</td>
#       <td id="T_9fd26_row7_col3" class="data row7 col3" >0.9475</td>
#       <td id="T_9fd26_row7_col4" class="data row7 col4" >0.1101</td>
#       <td id="T_9fd26_row7_col5" class="data row7 col5" >0.0809</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9fd26_row8_col0" class="data row8 col0" >171471.1116</td>
#       <td id="T_9fd26_row8_col1" class="data row8 col1" >164305412023.5836</td>
#       <td id="T_9fd26_row8_col2" class="data row8 col2" >405346.0399</td>
#       <td id="T_9fd26_row8_col3" class="data row8 col3" >0.9385</td>
#       <td id="T_9fd26_row8_col4" class="data row8 col4" >0.1161</td>
#       <td id="T_9fd26_row8_col5" class="data row8 col5" >0.0815</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9fd26_row9_col0" class="data row9 col0" >170974.2474</td>
#       <td id="T_9fd26_row9_col1" class="data row9 col1" >208097966959.5752</td>
#       <td id="T_9fd26_row9_col2" class="data row9 col2" >456177.5608</td>
#       <td id="T_9fd26_row9_col3" class="data row9 col3" >0.9272</td>
#       <td id="T_9fd26_row9_col4" class="data row9 col4" >0.1101</td>
#       <td id="T_9fd26_row9_col5" class="data row9 col5" >0.0787</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9fd26_row10_col0" class="data row10 col0" >168647.2197</td>
#       <td id="T_9fd26_row10_col1" class="data row10 col1" >162241678055.7826</td>
#       <td id="T_9fd26_row10_col2" class="data row10 col2" >400447.2053</td>
#       <td id="T_9fd26_row10_col3" class="data row10 col3" >0.9406</td>
#       <td id="T_9fd26_row10_col4" class="data row10 col4" >0.1098</td>
#       <td id="T_9fd26_row10_col5" class="data row10 col5" >0.0795</td>
#     </tr>
#     <tr>
#       <th id="T_9fd26_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9fd26_row11_col0" class="data row11 col0" >4328.0943</td>
#       <td id="T_9fd26_row11_col1" class="data row11 col1" >34668756726.5974</td>
#       <td id="T_9fd26_row11_col2" class="data row11 col2" >43401.7725</td>
#       <td id="T_9fd26_row11_col3" class="data row11 col3" >0.0111</td>
#       <td id="T_9fd26_row11_col4" class="data row11 col4" >0.0027</td>
#       <td id="T_9fd26_row11_col5" class="data row11 col5" >0.0012</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
bagged_tuned_xgboost = ensemble_model(tuned_xgboost, method = "Bagging")
# Out:
# <style type="text/css">
# #T_0eb08_row10_col0, #T_0eb08_row10_col1, #T_0eb08_row10_col2, #T_0eb08_row10_col3, #T_0eb08_row10_col4, #T_0eb08_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0eb08" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0eb08_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0eb08_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0eb08_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0eb08_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0eb08_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0eb08_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0eb08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0eb08_row0_col0" class="data row0 col0" >166872.0000</td>
#       <td id="T_0eb08_row0_col1" class="data row0 col1" >209460969472.0000</td>
#       <td id="T_0eb08_row0_col2" class="data row0 col2" >457669.0625</td>
#       <td id="T_0eb08_row0_col3" class="data row0 col3" >0.9264</td>
#       <td id="T_0eb08_row0_col4" class="data row0 col4" >0.1044</td>
#       <td id="T_0eb08_row0_col5" class="data row0 col5" >0.0734</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0eb08_row1_col0" class="data row1 col0" >156739.3750</td>
#       <td id="T_0eb08_row1_col1" class="data row1 col1" >145367367680.0000</td>
#       <td id="T_0eb08_row1_col2" class="data row1 col2" >381270.7188</td>
#       <td id="T_0eb08_row1_col3" class="data row1 col3" >0.9462</td>
#       <td id="T_0eb08_row1_col4" class="data row1 col4" >0.1003</td>
#       <td id="T_0eb08_row1_col5" class="data row1 col5" >0.0716</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0eb08_row2_col0" class="data row2 col0" >160582.8125</td>
#       <td id="T_0eb08_row2_col1" class="data row2 col1" >210449317888.0000</td>
#       <td id="T_0eb08_row2_col2" class="data row2 col2" >458747.5625</td>
#       <td id="T_0eb08_row2_col3" class="data row2 col3" >0.9301</td>
#       <td id="T_0eb08_row2_col4" class="data row2 col4" >0.1053</td>
#       <td id="T_0eb08_row2_col5" class="data row2 col5" >0.0708</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0eb08_row3_col0" class="data row3 col0" >157239.2969</td>
#       <td id="T_0eb08_row3_col1" class="data row3 col1" >162617065472.0000</td>
#       <td id="T_0eb08_row3_col2" class="data row3 col2" >403258.0625</td>
#       <td id="T_0eb08_row3_col3" class="data row3 col3" >0.9424</td>
#       <td id="T_0eb08_row3_col4" class="data row3 col4" >0.0983</td>
#       <td id="T_0eb08_row3_col5" class="data row3 col5" >0.0702</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0eb08_row4_col0" class="data row4 col0" >152390.0938</td>
#       <td id="T_0eb08_row4_col1" class="data row4 col1" >152997445632.0000</td>
#       <td id="T_0eb08_row4_col2" class="data row4 col2" >391148.8750</td>
#       <td id="T_0eb08_row4_col3" class="data row4 col3" >0.9323</td>
#       <td id="T_0eb08_row4_col4" class="data row4 col4" >0.0997</td>
#       <td id="T_0eb08_row4_col5" class="data row4 col5" >0.0706</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0eb08_row5_col0" class="data row5 col0" >149469.9531</td>
#       <td id="T_0eb08_row5_col1" class="data row5 col1" >112093855744.0000</td>
#       <td id="T_0eb08_row5_col2" class="data row5 col2" >334804.2188</td>
#       <td id="T_0eb08_row5_col3" class="data row5 col3" >0.9565</td>
#       <td id="T_0eb08_row5_col4" class="data row5 col4" >0.1002</td>
#       <td id="T_0eb08_row5_col5" class="data row5 col5" >0.0706</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0eb08_row6_col0" class="data row6 col0" >157560.7656</td>
#       <td id="T_0eb08_row6_col1" class="data row6 col1" >134650888192.0000</td>
#       <td id="T_0eb08_row6_col2" class="data row6 col2" >366948.0625</td>
#       <td id="T_0eb08_row6_col3" class="data row6 col3" >0.9543</td>
#       <td id="T_0eb08_row6_col4" class="data row6 col4" >0.0997</td>
#       <td id="T_0eb08_row6_col5" class="data row6 col5" >0.0715</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0eb08_row7_col0" class="data row7 col0" >157701.6719</td>
#       <td id="T_0eb08_row7_col1" class="data row7 col1" >148688519168.0000</td>
#       <td id="T_0eb08_row7_col2" class="data row7 col2" >385601.5000</td>
#       <td id="T_0eb08_row7_col3" class="data row7 col3" >0.9422</td>
#       <td id="T_0eb08_row7_col4" class="data row7 col4" >0.1021</td>
#       <td id="T_0eb08_row7_col5" class="data row7 col5" >0.0718</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0eb08_row8_col0" class="data row8 col0" >159623.0000</td>
#       <td id="T_0eb08_row8_col1" class="data row8 col1" >158731960320.0000</td>
#       <td id="T_0eb08_row8_col2" class="data row8 col2" >398411.8125</td>
#       <td id="T_0eb08_row8_col3" class="data row8 col3" >0.9406</td>
#       <td id="T_0eb08_row8_col4" class="data row8 col4" >0.1090</td>
#       <td id="T_0eb08_row8_col5" class="data row8 col5" >0.0734</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0eb08_row9_col0" class="data row9 col0" >156246.4062</td>
#       <td id="T_0eb08_row9_col1" class="data row9 col1" >198898237440.0000</td>
#       <td id="T_0eb08_row9_col2" class="data row9 col2" >445980.0938</td>
#       <td id="T_0eb08_row9_col3" class="data row9 col3" >0.9304</td>
#       <td id="T_0eb08_row9_col4" class="data row9 col4" >0.1018</td>
#       <td id="T_0eb08_row9_col5" class="data row9 col5" >0.0701</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0eb08_row10_col0" class="data row10 col0" >157442.5375</td>
#       <td id="T_0eb08_row10_col1" class="data row10 col1" >163395562700.8000</td>
#       <td id="T_0eb08_row10_col2" class="data row10 col2" >402383.9969</td>
#       <td id="T_0eb08_row10_col3" class="data row10 col3" >0.9401</td>
#       <td id="T_0eb08_row10_col4" class="data row10 col4" >0.1021</td>
#       <td id="T_0eb08_row10_col5" class="data row10 col5" >0.0714</td>
#     </tr>
#     <tr>
#       <th id="T_0eb08_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0eb08_row11_col0" class="data row11 col0" >4412.1129</td>
#       <td id="T_0eb08_row11_col1" class="data row11 col1" >31187221694.1656</td>
#       <td id="T_0eb08_row11_col2" class="data row11 col2" >38505.6287</td>
#       <td id="T_0eb08_row11_col3" class="data row11 col3" >0.0098</td>
#       <td id="T_0eb08_row11_col4" class="data row11 col4" >0.0031</td>
#       <td id="T_0eb08_row11_col5" class="data row11 col5" >0.0011</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
bagged_lightgbm = ensemble_model(lightgbm, method = "Bagging")
# Out:
# <style type="text/css">
# #T_846b4_row10_col0, #T_846b4_row10_col1, #T_846b4_row10_col2, #T_846b4_row10_col3, #T_846b4_row10_col4, #T_846b4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_846b4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_846b4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_846b4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_846b4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_846b4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_846b4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_846b4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_846b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_846b4_row0_col0" class="data row0 col0" >195132.2741</td>
#       <td id="T_846b4_row0_col1" class="data row0 col1" >224957477246.3822</td>
#       <td id="T_846b4_row0_col2" class="data row0 col2" >474296.8240</td>
#       <td id="T_846b4_row0_col3" class="data row0 col3" >0.9210</td>
#       <td id="T_846b4_row0_col4" class="data row0 col4" >0.1263</td>
#       <td id="T_846b4_row0_col5" class="data row0 col5" >0.0950</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_846b4_row1_col0" class="data row1 col0" >187506.9639</td>
#       <td id="T_846b4_row1_col1" class="data row1 col1" >163152356364.1508</td>
#       <td id="T_846b4_row1_col2" class="data row1 col2" >403921.2254</td>
#       <td id="T_846b4_row1_col3" class="data row1 col3" >0.9396</td>
#       <td id="T_846b4_row1_col4" class="data row1 col4" >0.1252</td>
#       <td id="T_846b4_row1_col5" class="data row1 col5" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_846b4_row2_col0" class="data row2 col0" >191389.4978</td>
#       <td id="T_846b4_row2_col1" class="data row2 col1" >236633157753.0982</td>
#       <td id="T_846b4_row2_col2" class="data row2 col2" >486449.5429</td>
#       <td id="T_846b4_row2_col3" class="data row2 col3" >0.9214</td>
#       <td id="T_846b4_row2_col4" class="data row2 col4" >0.1276</td>
#       <td id="T_846b4_row2_col5" class="data row2 col5" >0.0923</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_846b4_row3_col0" class="data row3 col0" >189983.7629</td>
#       <td id="T_846b4_row3_col1" class="data row3 col1" >188256021248.0436</td>
#       <td id="T_846b4_row3_col2" class="data row3 col2" >433884.8018</td>
#       <td id="T_846b4_row3_col3" class="data row3 col3" >0.9333</td>
#       <td id="T_846b4_row3_col4" class="data row3 col4" >0.1236</td>
#       <td id="T_846b4_row3_col5" class="data row3 col5" >0.0941</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_846b4_row4_col0" class="data row4 col0" >186462.1358</td>
#       <td id="T_846b4_row4_col1" class="data row4 col1" >170510113588.3334</td>
#       <td id="T_846b4_row4_col2" class="data row4 col2" >412928.7028</td>
#       <td id="T_846b4_row4_col3" class="data row4 col3" >0.9246</td>
#       <td id="T_846b4_row4_col4" class="data row4 col4" >0.1256</td>
#       <td id="T_846b4_row4_col5" class="data row4 col5" >0.0939</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_846b4_row5_col0" class="data row5 col0" >181981.9602</td>
#       <td id="T_846b4_row5_col1" class="data row5 col1" >126441987284.7609</td>
#       <td id="T_846b4_row5_col2" class="data row5 col2" >355586.8210</td>
#       <td id="T_846b4_row5_col3" class="data row5 col3" >0.9510</td>
#       <td id="T_846b4_row5_col4" class="data row5 col4" >0.1244</td>
#       <td id="T_846b4_row5_col5" class="data row5 col5" >0.0937</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_846b4_row6_col0" class="data row6 col0" >191776.4970</td>
#       <td id="T_846b4_row6_col1" class="data row6 col1" >158336127030.5292</td>
#       <td id="T_846b4_row6_col2" class="data row6 col2" >397914.7233</td>
#       <td id="T_846b4_row6_col3" class="data row6 col3" >0.9462</td>
#       <td id="T_846b4_row6_col4" class="data row6 col4" >0.1256</td>
#       <td id="T_846b4_row6_col5" class="data row6 col5" >0.0951</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_846b4_row7_col0" class="data row7 col0" >193132.2076</td>
#       <td id="T_846b4_row7_col1" class="data row7 col1" >160403665097.2796</td>
#       <td id="T_846b4_row7_col2" class="data row7 col2" >400504.2635</td>
#       <td id="T_846b4_row7_col3" class="data row7 col3" >0.9377</td>
#       <td id="T_846b4_row7_col4" class="data row7 col4" >0.1272</td>
#       <td id="T_846b4_row7_col5" class="data row7 col5" >0.0961</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_846b4_row8_col0" class="data row8 col0" >192378.3879</td>
#       <td id="T_846b4_row8_col1" class="data row8 col1" >182848621950.4250</td>
#       <td id="T_846b4_row8_col2" class="data row8 col2" >427608.0237</td>
#       <td id="T_846b4_row8_col3" class="data row8 col3" >0.9315</td>
#       <td id="T_846b4_row8_col4" class="data row8 col4" >0.1310</td>
#       <td id="T_846b4_row8_col5" class="data row8 col5" >0.0964</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_846b4_row9_col0" class="data row9 col0" >191927.0061</td>
#       <td id="T_846b4_row9_col1" class="data row9 col1" >230804318647.5681</td>
#       <td id="T_846b4_row9_col2" class="data row9 col2" >480420.9806</td>
#       <td id="T_846b4_row9_col3" class="data row9 col3" >0.9192</td>
#       <td id="T_846b4_row9_col4" class="data row9 col4" >0.1264</td>
#       <td id="T_846b4_row9_col5" class="data row9 col5" >0.0934</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_846b4_row10_col0" class="data row10 col0" >190167.0693</td>
#       <td id="T_846b4_row10_col1" class="data row10 col1" >184234384621.0571</td>
#       <td id="T_846b4_row10_col2" class="data row10 col2" >427351.5909</td>
#       <td id="T_846b4_row10_col3" class="data row10 col3" >0.9325</td>
#       <td id="T_846b4_row10_col4" class="data row10 col4" >0.1263</td>
#       <td id="T_846b4_row10_col5" class="data row10 col5" >0.0944</td>
#     </tr>
#     <tr>
#       <th id="T_846b4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_846b4_row11_col0" class="data row11 col0" >3651.7052</td>
#       <td id="T_846b4_row11_col1" class="data row11 col1" >34354397117.7106</td>
#       <td id="T_846b4_row11_col2" class="data row11 col2" >40062.4808</td>
#       <td id="T_846b4_row11_col3" class="data row11 col3" >0.0105</td>
#       <td id="T_846b4_row11_col4" class="data row11 col4" >0.0019</td>
#       <td id="T_846b4_row11_col5" class="data row11 col5" >0.0012</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
boosting_catboost = ensemble_model(catboost, method = "Boosting")
boosting_tuned_xgboost = ensemble_model(tuned_xgboost, method = "Boosting")
boosting_lightgbm = ensemble_model(lightgbm, method = "Boosting")
# Out:
# <style type="text/css">
# #T_10ed9_row10_col0, #T_10ed9_row10_col1, #T_10ed9_row10_col2, #T_10ed9_row10_col3, #T_10ed9_row10_col4, #T_10ed9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_10ed9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10ed9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_10ed9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_10ed9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_10ed9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_10ed9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_10ed9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10ed9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10ed9_row0_col0" class="data row0 col0" >178529.6774</td>
#       <td id="T_10ed9_row0_col1" class="data row0 col1" >193377989916.8174</td>
#       <td id="T_10ed9_row0_col2" class="data row0 col2" >439747.6434</td>
#       <td id="T_10ed9_row0_col3" class="data row0 col3" >0.9321</td>
#       <td id="T_10ed9_row0_col4" class="data row0 col4" >0.1144</td>
#       <td id="T_10ed9_row0_col5" class="data row0 col5" >0.0846</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10ed9_row1_col0" class="data row1 col0" >171457.5808</td>
#       <td id="T_10ed9_row1_col1" class="data row1 col1" >138056244623.1762</td>
#       <td id="T_10ed9_row1_col2" class="data row1 col2" >371559.2074</td>
#       <td id="T_10ed9_row1_col3" class="data row1 col3" >0.9489</td>
#       <td id="T_10ed9_row1_col4" class="data row1 col4" >0.1117</td>
#       <td id="T_10ed9_row1_col5" class="data row1 col5" >0.0840</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_10ed9_row2_col0" class="data row2 col0" >173824.5440</td>
#       <td id="T_10ed9_row2_col1" class="data row2 col1" >189499826331.6330</td>
#       <td id="T_10ed9_row2_col2" class="data row2 col2" >435315.7777</td>
#       <td id="T_10ed9_row2_col3" class="data row2 col3" >0.9371</td>
#       <td id="T_10ed9_row2_col4" class="data row2 col4" >0.1149</td>
#       <td id="T_10ed9_row2_col5" class="data row2 col5" >0.0824</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_10ed9_row3_col0" class="data row3 col0" >169743.7859</td>
#       <td id="T_10ed9_row3_col1" class="data row3 col1" >143650264911.2971</td>
#       <td id="T_10ed9_row3_col2" class="data row3 col2" >379012.2226</td>
#       <td id="T_10ed9_row3_col3" class="data row3 col3" >0.9491</td>
#       <td id="T_10ed9_row3_col4" class="data row3 col4" >0.1086</td>
#       <td id="T_10ed9_row3_col5" class="data row3 col5" >0.0820</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_10ed9_row4_col0" class="data row4 col0" >169626.0334</td>
#       <td id="T_10ed9_row4_col1" class="data row4 col1" >158636464090.6366</td>
#       <td id="T_10ed9_row4_col2" class="data row4 col2" >398291.9332</td>
#       <td id="T_10ed9_row4_col3" class="data row4 col3" >0.9298</td>
#       <td id="T_10ed9_row4_col4" class="data row4 col4" >0.1115</td>
#       <td id="T_10ed9_row4_col5" class="data row4 col5" >0.0837</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_10ed9_row5_col0" class="data row5 col0" >164646.7379</td>
#       <td id="T_10ed9_row5_col1" class="data row5 col1" >117123427013.5606</td>
#       <td id="T_10ed9_row5_col2" class="data row5 col2" >342233.0011</td>
#       <td id="T_10ed9_row5_col3" class="data row5 col3" >0.9546</td>
#       <td id="T_10ed9_row5_col4" class="data row5 col4" >0.1110</td>
#       <td id="T_10ed9_row5_col5" class="data row5 col5" >0.0824</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_10ed9_row6_col0" class="data row6 col0" >171214.5200</td>
#       <td id="T_10ed9_row6_col1" class="data row6 col1" >121059736586.6784</td>
#       <td id="T_10ed9_row6_col2" class="data row6 col2" >347936.3973</td>
#       <td id="T_10ed9_row6_col3" class="data row6 col3" >0.9589</td>
#       <td id="T_10ed9_row6_col4" class="data row6 col4" >0.1113</td>
#       <td id="T_10ed9_row6_col5" class="data row6 col5" >0.0847</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_10ed9_row7_col0" class="data row7 col0" >173753.3766</td>
#       <td id="T_10ed9_row7_col1" class="data row7 col1" >130115619266.3151</td>
#       <td id="T_10ed9_row7_col2" class="data row7 col2" >360715.4270</td>
#       <td id="T_10ed9_row7_col3" class="data row7 col3" >0.9494</td>
#       <td id="T_10ed9_row7_col4" class="data row7 col4" >0.1134</td>
#       <td id="T_10ed9_row7_col5" class="data row7 col5" >0.0846</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_10ed9_row8_col0" class="data row8 col0" >174445.5968</td>
#       <td id="T_10ed9_row8_col1" class="data row8 col1" >160183874870.0471</td>
#       <td id="T_10ed9_row8_col2" class="data row8 col2" >400229.7776</td>
#       <td id="T_10ed9_row8_col3" class="data row8 col3" >0.9400</td>
#       <td id="T_10ed9_row8_col4" class="data row8 col4" >0.1189</td>
#       <td id="T_10ed9_row8_col5" class="data row8 col5" >0.0856</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_10ed9_row9_col0" class="data row9 col0" >173478.8657</td>
#       <td id="T_10ed9_row9_col1" class="data row9 col1" >205676015321.0742</td>
#       <td id="T_10ed9_row9_col2" class="data row9 col2" >453515.1765</td>
#       <td id="T_10ed9_row9_col3" class="data row9 col3" >0.9280</td>
#       <td id="T_10ed9_row9_col4" class="data row9 col4" >0.1134</td>
#       <td id="T_10ed9_row9_col5" class="data row9 col5" >0.0829</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_10ed9_row10_col0" class="data row10 col0" >172072.0719</td>
#       <td id="T_10ed9_row10_col1" class="data row10 col1" >155737946293.1236</td>
#       <td id="T_10ed9_row10_col2" class="data row10 col2" >392855.6564</td>
#       <td id="T_10ed9_row10_col3" class="data row10 col3" >0.9428</td>
#       <td id="T_10ed9_row10_col4" class="data row10 col4" >0.1129</td>
#       <td id="T_10ed9_row10_col5" class="data row10 col5" >0.0837</td>
#     </tr>
#     <tr>
#       <th id="T_10ed9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_10ed9_row11_col0" class="data row11 col0" >3505.1947</td>
#       <td id="T_10ed9_row11_col1" class="data row11 col1" >29811966451.9811</td>
#       <td id="T_10ed9_row11_col2" class="data row11 col2" >37448.3582</td>
#       <td id="T_10ed9_row11_col3" class="data row11 col3" >0.0103</td>
#       <td id="T_10ed9_row11_col4" class="data row11 col4" >0.0027</td>
#       <td id="T_10ed9_row11_col5" class="data row11 col5" >0.0012</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_0af0b_row10_col0, #T_0af0b_row10_col1, #T_0af0b_row10_col2, #T_0af0b_row10_col3, #T_0af0b_row10_col4, #T_0af0b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0af0b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0af0b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0af0b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0af0b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0af0b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0af0b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0af0b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0af0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0af0b_row0_col0" class="data row0 col0" >162521.4219</td>
#       <td id="T_0af0b_row0_col1" class="data row0 col1" >189470572544.0000</td>
#       <td id="T_0af0b_row0_col2" class="data row0 col2" >435282.1875</td>
#       <td id="T_0af0b_row0_col3" class="data row0 col3" >0.9334</td>
#       <td id="T_0af0b_row0_col4" class="data row0 col4" >0.1019</td>
#       <td id="T_0af0b_row0_col5" class="data row0 col5" >0.0721</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0af0b_row1_col0" class="data row1 col0" >156049.2500</td>
#       <td id="T_0af0b_row1_col1" class="data row1 col1" >148857323520.0000</td>
#       <td id="T_0af0b_row1_col2" class="data row1 col2" >385820.3125</td>
#       <td id="T_0af0b_row1_col3" class="data row1 col3" >0.9449</td>
#       <td id="T_0af0b_row1_col4" class="data row1 col4" >0.0991</td>
#       <td id="T_0af0b_row1_col5" class="data row1 col5" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0af0b_row2_col0" class="data row2 col0" >160562.9375</td>
#       <td id="T_0af0b_row2_col1" class="data row2 col1" >221111435264.0000</td>
#       <td id="T_0af0b_row2_col2" class="data row2 col2" >470224.8750</td>
#       <td id="T_0af0b_row2_col3" class="data row2 col3" >0.9266</td>
#       <td id="T_0af0b_row2_col4" class="data row2 col4" >0.1039</td>
#       <td id="T_0af0b_row2_col5" class="data row2 col5" >0.0702</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0af0b_row3_col0" class="data row3 col0" >157034.9062</td>
#       <td id="T_0af0b_row3_col1" class="data row3 col1" >165390598144.0000</td>
#       <td id="T_0af0b_row3_col2" class="data row3 col2" >406682.4375</td>
#       <td id="T_0af0b_row3_col3" class="data row3 col3" >0.9414</td>
#       <td id="T_0af0b_row3_col4" class="data row3 col4" >0.0971</td>
#       <td id="T_0af0b_row3_col5" class="data row3 col5" >0.0698</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0af0b_row4_col0" class="data row4 col0" >152144.5156</td>
#       <td id="T_0af0b_row4_col1" class="data row4 col1" >163822403584.0000</td>
#       <td id="T_0af0b_row4_col2" class="data row4 col2" >404749.8125</td>
#       <td id="T_0af0b_row4_col3" class="data row4 col3" >0.9275</td>
#       <td id="T_0af0b_row4_col4" class="data row4 col4" >0.0993</td>
#       <td id="T_0af0b_row4_col5" class="data row4 col5" >0.0703</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0af0b_row5_col0" class="data row5 col0" >149570.7656</td>
#       <td id="T_0af0b_row5_col1" class="data row5 col1" >112820969472.0000</td>
#       <td id="T_0af0b_row5_col2" class="data row5 col2" >335888.3438</td>
#       <td id="T_0af0b_row5_col3" class="data row5 col3" >0.9563</td>
#       <td id="T_0af0b_row5_col4" class="data row5 col4" >0.0997</td>
#       <td id="T_0af0b_row5_col5" class="data row5 col5" >0.0703</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0af0b_row6_col0" class="data row6 col0" >155703.9531</td>
#       <td id="T_0af0b_row6_col1" class="data row6 col1" >127021957120.0000</td>
#       <td id="T_0af0b_row6_col2" class="data row6 col2" >356401.4062</td>
#       <td id="T_0af0b_row6_col3" class="data row6 col3" >0.9568</td>
#       <td id="T_0af0b_row6_col4" class="data row6 col4" >0.0983</td>
#       <td id="T_0af0b_row6_col5" class="data row6 col5" >0.0711</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0af0b_row7_col0" class="data row7 col0" >153311.3438</td>
#       <td id="T_0af0b_row7_col1" class="data row7 col1" >128875806720.0000</td>
#       <td id="T_0af0b_row7_col2" class="data row7 col2" >358992.7812</td>
#       <td id="T_0af0b_row7_col3" class="data row7 col3" >0.9499</td>
#       <td id="T_0af0b_row7_col4" class="data row7 col4" >0.1001</td>
#       <td id="T_0af0b_row7_col5" class="data row7 col5" >0.0707</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0af0b_row8_col0" class="data row8 col0" >159609.4375</td>
#       <td id="T_0af0b_row8_col1" class="data row8 col1" >160099729408.0000</td>
#       <td id="T_0af0b_row8_col2" class="data row8 col2" >400124.6562</td>
#       <td id="T_0af0b_row8_col3" class="data row8 col3" >0.9400</td>
#       <td id="T_0af0b_row8_col4" class="data row8 col4" >0.1072</td>
#       <td id="T_0af0b_row8_col5" class="data row8 col5" >0.0729</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0af0b_row9_col0" class="data row9 col0" >153012.8438</td>
#       <td id="T_0af0b_row9_col1" class="data row9 col1" >194657927168.0000</td>
#       <td id="T_0af0b_row9_col2" class="data row9 col2" >441200.5625</td>
#       <td id="T_0af0b_row9_col3" class="data row9 col3" >0.9319</td>
#       <td id="T_0af0b_row9_col4" class="data row9 col4" >0.1001</td>
#       <td id="T_0af0b_row9_col5" class="data row9 col5" >0.0691</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0af0b_row10_col0" class="data row10 col0" >155952.1375</td>
#       <td id="T_0af0b_row10_col1" class="data row10 col1" >161212872294.4000</td>
#       <td id="T_0af0b_row10_col2" class="data row10 col2" >399536.7375</td>
#       <td id="T_0af0b_row10_col3" class="data row10 col3" >0.9409</td>
#       <td id="T_0af0b_row10_col4" class="data row10 col4" >0.1007</td>
#       <td id="T_0af0b_row10_col5" class="data row10 col5" >0.0707</td>
#     </tr>
#     <tr>
#       <th id="T_0af0b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0af0b_row11_col0" class="data row11 col0" >3871.2706</td>
#       <td id="T_0af0b_row11_col1" class="data row11 col1" >31999296294.3626</td>
#       <td id="T_0af0b_row11_col2" class="data row11 col2" >39790.3690</td>
#       <td id="T_0af0b_row11_col3" class="data row11 col3" >0.0105</td>
#       <td id="T_0af0b_row11_col4" class="data row11 col4" >0.0028</td>
#       <td id="T_0af0b_row11_col5" class="data row11 col5" >0.0010</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_7f8f0_row10_col0, #T_7f8f0_row10_col1, #T_7f8f0_row10_col2, #T_7f8f0_row10_col3, #T_7f8f0_row10_col4, #T_7f8f0_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7f8f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f8f0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7f8f0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7f8f0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7f8f0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7f8f0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7f8f0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f8f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f8f0_row0_col0" class="data row0 col0" >203324.9249</td>
#       <td id="T_7f8f0_row0_col1" class="data row0 col1" >193118002272.5116</td>
#       <td id="T_7f8f0_row0_col2" class="data row0 col2" >439451.9340</td>
#       <td id="T_7f8f0_row0_col3" class="data row0 col3" >0.9322</td>
#       <td id="T_7f8f0_row0_col4" class="data row0 col4" >0.1333</td>
#       <td id="T_7f8f0_row0_col5" class="data row0 col5" >0.1048</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f8f0_row1_col0" class="data row1 col0" >198627.9703</td>
#       <td id="T_7f8f0_row1_col1" class="data row1 col1" >155802799266.5214</td>
#       <td id="T_7f8f0_row1_col2" class="data row1 col2" >394718.6330</td>
#       <td id="T_7f8f0_row1_col3" class="data row1 col3" >0.9423</td>
#       <td id="T_7f8f0_row1_col4" class="data row1 col4" >0.1320</td>
#       <td id="T_7f8f0_row1_col5" class="data row1 col5" >0.1033</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f8f0_row2_col0" class="data row2 col0" >200142.7957</td>
#       <td id="T_7f8f0_row2_col1" class="data row2 col1" >203420056364.1513</td>
#       <td id="T_7f8f0_row2_col2" class="data row2 col2" >451021.1263</td>
#       <td id="T_7f8f0_row2_col3" class="data row2 col3" >0.9324</td>
#       <td id="T_7f8f0_row2_col4" class="data row2 col4" >0.1345</td>
#       <td id="T_7f8f0_row2_col5" class="data row2 col5" >0.1022</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f8f0_row3_col0" class="data row3 col0" >197720.2474</td>
#       <td id="T_7f8f0_row3_col1" class="data row3 col1" >158043057135.6343</td>
#       <td id="T_7f8f0_row3_col2" class="data row3 col2" >397546.2956</td>
#       <td id="T_7f8f0_row3_col3" class="data row3 col3" >0.9440</td>
#       <td id="T_7f8f0_row3_col4" class="data row3 col4" >0.1321</td>
#       <td id="T_7f8f0_row3_col5" class="data row3 col5" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f8f0_row4_col0" class="data row4 col0" >194282.8989</td>
#       <td id="T_7f8f0_row4_col1" class="data row4 col1" >182167121662.6377</td>
#       <td id="T_7f8f0_row4_col2" class="data row4 col2" >426810.4048</td>
#       <td id="T_7f8f0_row4_col3" class="data row4 col3" >0.9194</td>
#       <td id="T_7f8f0_row4_col4" class="data row4 col4" >0.1322</td>
#       <td id="T_7f8f0_row4_col5" class="data row4 col5" >0.1018</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7f8f0_row5_col0" class="data row5 col0" >191122.2914</td>
#       <td id="T_7f8f0_row5_col1" class="data row5 col1" >127352570118.7818</td>
#       <td id="T_7f8f0_row5_col2" class="data row5 col2" >356864.9186</td>
#       <td id="T_7f8f0_row5_col3" class="data row5 col3" >0.9506</td>
#       <td id="T_7f8f0_row5_col4" class="data row5 col4" >0.1328</td>
#       <td id="T_7f8f0_row5_col5" class="data row5 col5" >0.1029</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7f8f0_row6_col0" class="data row6 col0" >198769.4924</td>
#       <td id="T_7f8f0_row6_col1" class="data row6 col1" >144869359448.6486</td>
#       <td id="T_7f8f0_row6_col2" class="data row6 col2" >380617.0772</td>
#       <td id="T_7f8f0_row6_col3" class="data row6 col3" >0.9508</td>
#       <td id="T_7f8f0_row6_col4" class="data row6 col4" >0.1341</td>
#       <td id="T_7f8f0_row6_col5" class="data row6 col5" >0.1050</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7f8f0_row7_col0" class="data row7 col0" >198495.5730</td>
#       <td id="T_7f8f0_row7_col1" class="data row7 col1" >142073859490.7576</td>
#       <td id="T_7f8f0_row7_col2" class="data row7 col2" >376926.8623</td>
#       <td id="T_7f8f0_row7_col3" class="data row7 col3" >0.9448</td>
#       <td id="T_7f8f0_row7_col4" class="data row7 col4" >0.1344</td>
#       <td id="T_7f8f0_row7_col5" class="data row7 col5" >0.1043</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7f8f0_row8_col0" class="data row8 col0" >200711.1672</td>
#       <td id="T_7f8f0_row8_col1" class="data row8 col1" >176588044144.8353</td>
#       <td id="T_7f8f0_row8_col2" class="data row8 col2" >420223.8024</td>
#       <td id="T_7f8f0_row8_col3" class="data row8 col3" >0.9339</td>
#       <td id="T_7f8f0_row8_col4" class="data row8 col4" >0.1372</td>
#       <td id="T_7f8f0_row8_col5" class="data row8 col5" >0.1045</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7f8f0_row9_col0" class="data row9 col0" >197668.8862</td>
#       <td id="T_7f8f0_row9_col1" class="data row9 col1" >219026178529.9901</td>
#       <td id="T_7f8f0_row9_col2" class="data row9 col2" >468002.3275</td>
#       <td id="T_7f8f0_row9_col3" class="data row9 col3" >0.9233</td>
#       <td id="T_7f8f0_row9_col4" class="data row9 col4" >0.1322</td>
#       <td id="T_7f8f0_row9_col5" class="data row9 col5" >0.1012</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7f8f0_row10_col0" class="data row10 col0" >198086.6247</td>
#       <td id="T_7f8f0_row10_col1" class="data row10 col1" >170246104843.4470</td>
#       <td id="T_7f8f0_row10_col2" class="data row10 col2" >411218.3382</td>
#       <td id="T_7f8f0_row10_col3" class="data row10 col3" >0.9374</td>
#       <td id="T_7f8f0_row10_col4" class="data row10 col4" >0.1335</td>
#       <td id="T_7f8f0_row10_col5" class="data row10 col5" >0.1033</td>
#     </tr>
#     <tr>
#       <th id="T_7f8f0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7f8f0_row11_col0" class="data row11 col0" >3205.6428</td>
#       <td id="T_7f8f0_row11_col1" class="data row11 col1" >27965147169.3650</td>
#       <td id="T_7f8f0_row11_col2" class="data row11 col2" >33846.4651</td>
#       <td id="T_7f8f0_row11_col3" class="data row11 col3" >0.0103</td>
#       <td id="T_7f8f0_row11_col4" class="data row11 col4" >0.0015</td>
#       <td id="T_7f8f0_row11_col5" class="data row11 col5" >0.0012</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
et = create_model("et")
rf = create_model("rf")
boosting_et = ensemble_model(et, method = "Boosting")
boosting_rf = ensemble_model(rf, method = "Boosting")
# Out:
# <style type="text/css">
# #T_c33fa_row10_col0, #T_c33fa_row10_col1, #T_c33fa_row10_col2, #T_c33fa_row10_col3, #T_c33fa_row10_col4, #T_c33fa_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c33fa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c33fa_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c33fa_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c33fa_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c33fa_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c33fa_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c33fa_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c33fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c33fa_row0_col0" class="data row0 col0" >158996.3744</td>
#       <td id="T_c33fa_row0_col1" class="data row0 col1" >201189239822.3940</td>
#       <td id="T_c33fa_row0_col2" class="data row0 col2" >448541.2354</td>
#       <td id="T_c33fa_row0_col3" class="data row0 col3" >0.9293</td>
#       <td id="T_c33fa_row0_col4" class="data row0 col4" >0.1015</td>
#       <td id="T_c33fa_row0_col5" class="data row0 col5" >0.0694</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c33fa_row1_col0" class="data row1 col0" >151673.7151</td>
#       <td id="T_c33fa_row1_col1" class="data row1 col1" >142721370670.5925</td>
#       <td id="T_c33fa_row1_col2" class="data row1 col2" >377784.8206</td>
#       <td id="T_c33fa_row1_col3" class="data row1 col3" >0.9472</td>
#       <td id="T_c33fa_row1_col4" class="data row1 col4" >0.0994</td>
#       <td id="T_c33fa_row1_col5" class="data row1 col5" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c33fa_row2_col0" class="data row2 col0" >152318.3013</td>
#       <td id="T_c33fa_row2_col1" class="data row2 col1" >203145578774.6304</td>
#       <td id="T_c33fa_row2_col2" class="data row2 col2" >450716.7390</td>
#       <td id="T_c33fa_row2_col3" class="data row2 col3" >0.9325</td>
#       <td id="T_c33fa_row2_col4" class="data row2 col4" >0.1011</td>
#       <td id="T_c33fa_row2_col5" class="data row2 col5" >0.0664</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c33fa_row3_col0" class="data row3 col0" >152361.7510</td>
#       <td id="T_c33fa_row3_col1" class="data row3 col1" >172455068946.1061</td>
#       <td id="T_c33fa_row3_col2" class="data row3 col2" >415277.0990</td>
#       <td id="T_c33fa_row3_col3" class="data row3 col3" >0.9389</td>
#       <td id="T_c33fa_row3_col4" class="data row3 col4" >0.0969</td>
#       <td id="T_c33fa_row3_col5" class="data row3 col5" >0.0667</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c33fa_row4_col0" class="data row4 col0" >151118.1301</td>
#       <td id="T_c33fa_row4_col1" class="data row4 col1" >175108286760.2752</td>
#       <td id="T_c33fa_row4_col2" class="data row4 col2" >418459.4207</td>
#       <td id="T_c33fa_row4_col3" class="data row4 col3" >0.9225</td>
#       <td id="T_c33fa_row4_col4" class="data row4 col4" >0.0999</td>
#       <td id="T_c33fa_row4_col5" class="data row4 col5" >0.0686</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c33fa_row5_col0" class="data row5 col0" >144549.2190</td>
#       <td id="T_c33fa_row5_col1" class="data row5 col1" >115717177507.5704</td>
#       <td id="T_c33fa_row5_col2" class="data row5 col2" >340172.2762</td>
#       <td id="T_c33fa_row5_col3" class="data row5 col3" >0.9551</td>
#       <td id="T_c33fa_row5_col4" class="data row5 col4" >0.1002</td>
#       <td id="T_c33fa_row5_col5" class="data row5 col5" >0.0682</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c33fa_row6_col0" class="data row6 col0" >152218.9177</td>
#       <td id="T_c33fa_row6_col1" class="data row6 col1" >130262132611.8727</td>
#       <td id="T_c33fa_row6_col2" class="data row6 col2" >360918.4570</td>
#       <td id="T_c33fa_row6_col3" class="data row6 col3" >0.9557</td>
#       <td id="T_c33fa_row6_col4" class="data row6 col4" >0.0992</td>
#       <td id="T_c33fa_row6_col5" class="data row6 col5" >0.0694</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c33fa_row7_col0" class="data row7 col0" >152202.3936</td>
#       <td id="T_c33fa_row7_col1" class="data row7 col1" >141360820814.1202</td>
#       <td id="T_c33fa_row7_col2" class="data row7 col2" >375979.8144</td>
#       <td id="T_c33fa_row7_col3" class="data row7 col3" >0.9451</td>
#       <td id="T_c33fa_row7_col4" class="data row7 col4" >0.0996</td>
#       <td id="T_c33fa_row7_col5" class="data row7 col5" >0.0688</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c33fa_row8_col0" class="data row8 col0" >154936.6256</td>
#       <td id="T_c33fa_row8_col1" class="data row8 col1" >151505430603.4804</td>
#       <td id="T_c33fa_row8_col2" class="data row8 col2" >389236.9851</td>
#       <td id="T_c33fa_row8_col3" class="data row8 col3" >0.9433</td>
#       <td id="T_c33fa_row8_col4" class="data row8 col4" >0.1072</td>
#       <td id="T_c33fa_row8_col5" class="data row8 col5" >0.0712</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c33fa_row9_col0" class="data row9 col0" >149725.3349</td>
#       <td id="T_c33fa_row9_col1" class="data row9 col1" >197423727897.0062</td>
#       <td id="T_c33fa_row9_col2" class="data row9 col2" >444323.8998</td>
#       <td id="T_c33fa_row9_col3" class="data row9 col3" >0.9309</td>
#       <td id="T_c33fa_row9_col4" class="data row9 col4" >0.0979</td>
#       <td id="T_c33fa_row9_col5" class="data row9 col5" >0.0657</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c33fa_row10_col0" class="data row10 col0" >152010.0763</td>
#       <td id="T_c33fa_row10_col1" class="data row10 col1" >163088883440.8048</td>
#       <td id="T_c33fa_row10_col2" class="data row10 col2" >402141.0747</td>
#       <td id="T_c33fa_row10_col3" class="data row10 col3" >0.9401</td>
#       <td id="T_c33fa_row10_col4" class="data row10 col4" >0.1003</td>
#       <td id="T_c33fa_row10_col5" class="data row10 col5" >0.0683</td>
#     </tr>
#     <tr>
#       <th id="T_c33fa_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c33fa_row11_col0" class="data row11 col0" >3456.3778</td>
#       <td id="T_c33fa_row11_col1" class="data row11 col1" >29681717913.5178</td>
#       <td id="T_c33fa_row11_col2" class="data row11 col2" >37032.9512</td>
#       <td id="T_c33fa_row11_col3" class="data row11 col3" >0.0106</td>
#       <td id="T_c33fa_row11_col4" class="data row11 col4" >0.0027</td>
#       <td id="T_c33fa_row11_col5" class="data row11 col5" >0.0016</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_ad26f_row10_col0, #T_ad26f_row10_col1, #T_ad26f_row10_col2, #T_ad26f_row10_col3, #T_ad26f_row10_col4, #T_ad26f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ad26f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad26f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ad26f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ad26f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ad26f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ad26f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ad26f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad26f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad26f_row0_col0" class="data row0 col0" >173265.9071</td>
#       <td id="T_ad26f_row0_col1" class="data row0 col1" >238335439600.0136</td>
#       <td id="T_ad26f_row0_col2" class="data row0 col2" >488196.1077</td>
#       <td id="T_ad26f_row0_col3" class="data row0 col3" >0.9163</td>
#       <td id="T_ad26f_row0_col4" class="data row0 col4" >0.1107</td>
#       <td id="T_ad26f_row0_col5" class="data row0 col5" >0.0754</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad26f_row1_col0" class="data row1 col0" >165387.1359</td>
#       <td id="T_ad26f_row1_col1" class="data row1 col1" >176683617121.4718</td>
#       <td id="T_ad26f_row1_col2" class="data row1 col2" >420337.5038</td>
#       <td id="T_ad26f_row1_col3" class="data row1 col3" >0.9346</td>
#       <td id="T_ad26f_row1_col4" class="data row1 col4" >0.1060</td>
#       <td id="T_ad26f_row1_col5" class="data row1 col5" >0.0745</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad26f_row2_col0" class="data row2 col0" >172761.3532</td>
#       <td id="T_ad26f_row2_col1" class="data row2 col1" >275305004760.9278</td>
#       <td id="T_ad26f_row2_col2" class="data row2 col2" >524695.1541</td>
#       <td id="T_ad26f_row2_col3" class="data row2 col3" >0.9086</td>
#       <td id="T_ad26f_row2_col4" class="data row2 col4" >0.1135</td>
#       <td id="T_ad26f_row2_col5" class="data row2 col5" >0.0739</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad26f_row3_col0" class="data row3 col0" >167312.6332</td>
#       <td id="T_ad26f_row3_col1" class="data row3 col1" >199568746757.0362</td>
#       <td id="T_ad26f_row3_col2" class="data row3 col2" >446731.1795</td>
#       <td id="T_ad26f_row3_col3" class="data row3 col3" >0.9293</td>
#       <td id="T_ad26f_row3_col4" class="data row3 col4" >0.1054</td>
#       <td id="T_ad26f_row3_col5" class="data row3 col5" >0.0733</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad26f_row4_col0" class="data row4 col0" >165430.3000</td>
#       <td id="T_ad26f_row4_col1" class="data row4 col1" >201439255897.4436</td>
#       <td id="T_ad26f_row4_col2" class="data row4 col2" >448819.8479</td>
#       <td id="T_ad26f_row4_col3" class="data row4 col3" >0.9109</td>
#       <td id="T_ad26f_row4_col4" class="data row4 col4" >0.1089</td>
#       <td id="T_ad26f_row4_col5" class="data row4 col5" >0.0747</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad26f_row5_col0" class="data row5 col0" >156545.2303</td>
#       <td id="T_ad26f_row5_col1" class="data row5 col1" >128522671586.8886</td>
#       <td id="T_ad26f_row5_col2" class="data row5 col2" >358500.5880</td>
#       <td id="T_ad26f_row5_col3" class="data row5 col3" >0.9502</td>
#       <td id="T_ad26f_row5_col4" class="data row5 col4" >0.1056</td>
#       <td id="T_ad26f_row5_col5" class="data row5 col5" >0.0732</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ad26f_row6_col0" class="data row6 col0" >170176.0250</td>
#       <td id="T_ad26f_row6_col1" class="data row6 col1" >171912116136.0736</td>
#       <td id="T_ad26f_row6_col2" class="data row6 col2" >414622.8601</td>
#       <td id="T_ad26f_row6_col3" class="data row6 col3" >0.9416</td>
#       <td id="T_ad26f_row6_col4" class="data row6 col4" >0.1080</td>
#       <td id="T_ad26f_row6_col5" class="data row6 col5" >0.0759</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ad26f_row7_col0" class="data row7 col0" >167339.6119</td>
#       <td id="T_ad26f_row7_col1" class="data row7 col1" >183373121149.8036</td>
#       <td id="T_ad26f_row7_col2" class="data row7 col2" >428220.8789</td>
#       <td id="T_ad26f_row7_col3" class="data row7 col3" >0.9287</td>
#       <td id="T_ad26f_row7_col4" class="data row7 col4" >0.1078</td>
#       <td id="T_ad26f_row7_col5" class="data row7 col5" >0.0744</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ad26f_row8_col0" class="data row8 col0" >168741.3455</td>
#       <td id="T_ad26f_row8_col1" class="data row8 col1" >179761908282.7060</td>
#       <td id="T_ad26f_row8_col2" class="data row8 col2" >423983.3821</td>
#       <td id="T_ad26f_row8_col3" class="data row8 col3" >0.9327</td>
#       <td id="T_ad26f_row8_col4" class="data row8 col4" >0.1157</td>
#       <td id="T_ad26f_row8_col5" class="data row8 col5" >0.0773</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ad26f_row9_col0" class="data row9 col0" >165817.1518</td>
#       <td id="T_ad26f_row9_col1" class="data row9 col1" >222359795831.7846</td>
#       <td id="T_ad26f_row9_col2" class="data row9 col2" >471550.4171</td>
#       <td id="T_ad26f_row9_col3" class="data row9 col3" >0.9222</td>
#       <td id="T_ad26f_row9_col4" class="data row9 col4" >0.1070</td>
#       <td id="T_ad26f_row9_col5" class="data row9 col5" >0.0725</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ad26f_row10_col0" class="data row10 col0" >167277.6694</td>
#       <td id="T_ad26f_row10_col1" class="data row10 col1" >197726167712.4150</td>
#       <td id="T_ad26f_row10_col2" class="data row10 col2" >442565.7919</td>
#       <td id="T_ad26f_row10_col3" class="data row10 col3" >0.9275</td>
#       <td id="T_ad26f_row10_col4" class="data row10 col4" >0.1089</td>
#       <td id="T_ad26f_row10_col5" class="data row10 col5" >0.0745</td>
#     </tr>
#     <tr>
#       <th id="T_ad26f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ad26f_row11_col0" class="data row11 col0" >4480.8805</td>
#       <td id="T_ad26f_row11_col1" class="data row11 col1" >38364813709.1920</td>
#       <td id="T_ad26f_row11_col2" class="data row11 col2" >43147.2771</td>
#       <td id="T_ad26f_row11_col3" class="data row11 col3" >0.0126</td>
#       <td id="T_ad26f_row11_col4" class="data row11 col4" >0.0033</td>
#       <td id="T_ad26f_row11_col5" class="data row11 col5" >0.0013</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          07:49:53
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .               str
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]

# %% [markdown]
# Choose 6 best algorithm result to be estimator in stacking regressor.

# %%
stacker = stack_models(estimator_list=[et, rf, catboost, tuned_xgboost, lightgbm, bagged_catboost])
# Out:
# <style type="text/css">
# #T_b3ee7_row10_col0, #T_b3ee7_row10_col1, #T_b3ee7_row10_col2, #T_b3ee7_row10_col3, #T_b3ee7_row10_col4, #T_b3ee7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b3ee7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3ee7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b3ee7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b3ee7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b3ee7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b3ee7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b3ee7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3ee7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3ee7_row0_col0" class="data row0 col0" >154292.9282</td>
#       <td id="T_b3ee7_row0_col1" class="data row0 col1" >182778106339.1147</td>
#       <td id="T_b3ee7_row0_col2" class="data row0 col2" >427525.5622</td>
#       <td id="T_b3ee7_row0_col3" class="data row0 col3" >0.9358</td>
#       <td id="T_b3ee7_row0_col4" class="data row0 col4" >0.0995</td>
#       <td id="T_b3ee7_row0_col5" class="data row0 col5" >0.0687</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3ee7_row1_col0" class="data row1 col0" >148279.9514</td>
#       <td id="T_b3ee7_row1_col1" class="data row1 col1" >128668347644.7600</td>
#       <td id="T_b3ee7_row1_col2" class="data row1 col2" >358703.7045</td>
#       <td id="T_b3ee7_row1_col3" class="data row1 col3" >0.9524</td>
#       <td id="T_b3ee7_row1_col4" class="data row1 col4" >0.0971</td>
#       <td id="T_b3ee7_row1_col5" class="data row1 col5" >0.0681</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3ee7_row2_col0" class="data row2 col0" >154587.4930</td>
#       <td id="T_b3ee7_row2_col1" class="data row2 col1" >198979350741.8752</td>
#       <td id="T_b3ee7_row2_col2" class="data row2 col2" >446071.0154</td>
#       <td id="T_b3ee7_row2_col3" class="data row2 col3" >0.9339</td>
#       <td id="T_b3ee7_row2_col4" class="data row2 col4" >0.1024</td>
#       <td id="T_b3ee7_row2_col5" class="data row2 col5" >0.0677</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3ee7_row3_col0" class="data row3 col0" >148775.3739</td>
#       <td id="T_b3ee7_row3_col1" class="data row3 col1" >141043239876.1543</td>
#       <td id="T_b3ee7_row3_col2" class="data row3 col2" >375557.2391</td>
#       <td id="T_b3ee7_row3_col3" class="data row3 col3" >0.9500</td>
#       <td id="T_b3ee7_row3_col4" class="data row3 col4" >0.0934</td>
#       <td id="T_b3ee7_row3_col5" class="data row3 col5" >0.0659</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3ee7_row4_col0" class="data row4 col0" >148303.3482</td>
#       <td id="T_b3ee7_row4_col1" class="data row4 col1" >168901501880.7522</td>
#       <td id="T_b3ee7_row4_col2" class="data row4 col2" >410976.2790</td>
#       <td id="T_b3ee7_row4_col3" class="data row4 col3" >0.9253</td>
#       <td id="T_b3ee7_row4_col4" class="data row4 col4" >0.0967</td>
#       <td id="T_b3ee7_row4_col5" class="data row4 col5" >0.0677</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3ee7_row5_col0" class="data row5 col0" >141704.0134</td>
#       <td id="T_b3ee7_row5_col1" class="data row5 col1" >96670344846.5965</td>
#       <td id="T_b3ee7_row5_col2" class="data row5 col2" >310918.5502</td>
#       <td id="T_b3ee7_row5_col3" class="data row5 col3" >0.9625</td>
#       <td id="T_b3ee7_row5_col4" class="data row5 col4" >0.0973</td>
#       <td id="T_b3ee7_row5_col5" class="data row5 col5" >0.0676</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3ee7_row6_col0" class="data row6 col0" >147293.4553</td>
#       <td id="T_b3ee7_row6_col1" class="data row6 col1" >110975314202.0903</td>
#       <td id="T_b3ee7_row6_col2" class="data row6 col2" >333129.5757</td>
#       <td id="T_b3ee7_row6_col3" class="data row6 col3" >0.9623</td>
#       <td id="T_b3ee7_row6_col4" class="data row6 col4" >0.0948</td>
#       <td id="T_b3ee7_row6_col5" class="data row6 col5" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3ee7_row7_col0" class="data row7 col0" >147936.7764</td>
#       <td id="T_b3ee7_row7_col1" class="data row7 col1" >124493959750.7990</td>
#       <td id="T_b3ee7_row7_col2" class="data row7 col2" >352837.0158</td>
#       <td id="T_b3ee7_row7_col3" class="data row7 col3" >0.9516</td>
#       <td id="T_b3ee7_row7_col4" class="data row7 col4" >0.0959</td>
#       <td id="T_b3ee7_row7_col5" class="data row7 col5" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3ee7_row8_col0" class="data row8 col0" >153347.5471</td>
#       <td id="T_b3ee7_row8_col1" class="data row8 col1" >145204859348.5030</td>
#       <td id="T_b3ee7_row8_col2" class="data row8 col2" >381057.5539</td>
#       <td id="T_b3ee7_row8_col3" class="data row8 col3" >0.9456</td>
#       <td id="T_b3ee7_row8_col4" class="data row8 col4" >0.1066</td>
#       <td id="T_b3ee7_row8_col5" class="data row8 col5" >0.0707</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3ee7_row9_col0" class="data row9 col0" >151195.9345</td>
#       <td id="T_b3ee7_row9_col1" class="data row9 col1" >185133301777.8306</td>
#       <td id="T_b3ee7_row9_col2" class="data row9 col2" >430271.1956</td>
#       <td id="T_b3ee7_row9_col3" class="data row9 col3" >0.9352</td>
#       <td id="T_b3ee7_row9_col4" class="data row9 col4" >0.0972</td>
#       <td id="T_b3ee7_row9_col5" class="data row9 col5" >0.0672</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b3ee7_row10_col0" class="data row10 col0" >149571.6821</td>
#       <td id="T_b3ee7_row10_col1" class="data row10 col1" >148284832640.8476</td>
#       <td id="T_b3ee7_row10_col2" class="data row10 col2" >382704.7691</td>
#       <td id="T_b3ee7_row10_col3" class="data row10 col3" >0.9455</td>
#       <td id="T_b3ee7_row10_col4" class="data row10 col4" >0.0981</td>
#       <td id="T_b3ee7_row10_col5" class="data row10 col5" >0.0679</td>
#     </tr>
#     <tr>
#       <th id="T_b3ee7_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b3ee7_row11_col0" class="data row11 col0" >3715.0864</td>
#       <td id="T_b3ee7_row11_col1" class="data row11 col1" >32575099935.8775</td>
#       <td id="T_b3ee7_row11_col2" class="data row11 col2" >42683.6306</td>
#       <td id="T_b3ee7_row11_col3" class="data row11 col3" >0.0119</td>
#       <td id="T_b3ee7_row11_col4" class="data row11 col4" >0.0037</td>
#       <td id="T_b3ee7_row11_col5" class="data row11 col5" >0.0012</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]

# %% [markdown]
# finalize the model (fit all the data)

# %%
final_stacker = finalize_model(stacker)

# %%
test.drop(["price"], axis = 1, inplace = True)

# %%
pred_test = predict_model(stacker, data = test)

# %%
save_model(stacker,'stacker_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(include=['date'],
#                                      transformer=ExtractDateTimeFeatures())),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['area', 'InterestRate',
#                                               'RentIndex', 'Available', 'Vacant',
#                                               'lat', 'lng'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(inc...
#                                                               monotone_constraints=None,
#                                                               n_estimators=290,
#                                                               n_jobs=-1,
#                                                               num_parallel_tree=None,
#                                                               predictor=None,
#                                                               random_state=123, ...)),
#                                                 ('Light Gradient Boosting '
#                                                  'Machine',
#                                                  LGBMRegressor(random_state=123)),
#                                                 ('str',
#                                                  BaggingRegressor(estimator=<catboost.core.CatBoostRegressor object at 0x7f50497f9e50>,
#                                                                   random_state=123))],
#                                     final_estimator=LinearRegression(n_jobs=-1),
#                                     n_jobs=-1, passthrough=True))]),
#  'stacker_model.pkl')

# %%
pred_test
# Out:
#         area  district  typeOfArea  tenure            street  \
# 32     249.0         4           1       0        COVE DRIVE
# 36     202.0         4           1       0        COVE DRIVE
# 44      75.0         7           1       0        BEACH ROAD
# 68      84.0         7           1       0        BEACH ROAD
# 79      84.0         7           1       0        BEACH ROAD
# ...      ...       ...         ...     ...               ...
# 65246   65.0        27           1       0  YISHUN CENTRAL 1
# 65247   65.0        27           1       0  YISHUN CENTRAL 1
# 65252   52.0        27           1       0  YISHUN CENTRAL 1
# 65258   80.0        27           1       0  YISHUN CENTRAL 1
# 65263  112.0        27           1       0  YISHUN CENTRAL 1
#
#                      project property_key       date  train         CPI  ...  \
# 32                 TURQUOISE  p-940dd9922 2023-01-01      0  109.892998  ...
# 36                 TURQUOISE  p-72a9ac344 2023-02-01      0  110.959000  ...
# 44                 CITY GATE  p-3bd67ad7e 2023-03-01      0  111.185997  ...
# 68                 CITY GATE  p-0ba6a9779 2023-01-01      0  109.892998  ...
# 79                 CITY GATE  p-98a2eb94e 2023-01-01      0  109.892998  ...
# ...                      ...          ...        ...    ...         ...  ...
# 65246  NORTH PARK RESIDENCES  p-88070a1d9 2023-02-01      0  110.959000  ...
# 65247  NORTH PARK RESIDENCES  p-88070a1d9 2023-03-01      0  111.185997  ...
# 65252  NORTH PARK RESIDENCES  p-8bd80748c 2023-03-01      0  111.185997  ...
# 65258  NORTH PARK RESIDENCES  p-be2eb0456 2023-01-01      0  109.892998  ...
# 65263  NORTH PARK RESIDENCES  p-f91f4bb4f 2023-03-01      0  111.185997  ...
#
#        Executive Condominium  Semi-detached  Strata Detached  \
# 32                         0              0                0
# 36                         0              0                0
# 44                         0              0                0
# 68                         0              0                0
# 79                         0              0                0
# ...                      ...            ...              ...
# 65246                      0              0                0
# 65247                      0              0                0
# 65252                      0              0                0
# 65258                      0              0                0
# 65263                      0              0                0
#
#        Strata Semi-detached  Strata Terrace  Terrace  CCR  OCR  RCR  \
# 32                        0               0        0    1    0    0
# 36                        0               0        0    1    0    0
# 44                        0               0        0    0    0    1
# 68                        0               0        0    0    0    1
# 79                        0               0        0    0    0    1
# ...                     ...             ...      ...  ...  ...  ...
# 65246                     0               0        0    0    1    0
# 65247                     0               0        0    0    1    0
# 65252                     0               0        0    0    1    0
# 65258                     0               0        0    0    1    0
# 65263                     0               0        0    0    1    0
#
#        prediction_label
# 32         4.351370e+06
# 36         3.290323e+06
# 44         1.498514e+06
# 68         1.647733e+06
# 79         1.683622e+06
# ...                 ...
# 65246      1.151461e+06
# 65247      1.155746e+06
# 65252      8.919497e+05
# 65258      1.222669e+06
# 65263      1.739235e+06
#
# [2331 rows x 36 columns]

# %%
predDf = pd.DataFrame({"property_key" : pred_test["property_key"],
                       "contractDate" : pred_test["date"],})
predDf = predDf.assign(prediction = pred_test["prediction_label"])
predDf.to_csv("Submission.csv", index = False)
